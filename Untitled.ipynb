# %%
# !pip list
# Out:
# Package                               Version
# ------------------------------------- ----------------
# absl-py                               2.1.0
# accelerate                            0.21.0
# aiobotocore                           2.12.2
# aiohttp                               3.9.3
# aioitertools                          0.11.0
# aiosignal                             1.3.1
# aiosqlite                             0.19.0
# altair                                5.3.0
# amazon-codewhisperer-jupyterlab-ext   2.0.1
# amazon_sagemaker_jupyter_scheduler    3.0.7
# amazon-sagemaker-sql-editor           0.1.5
# amazon-sagemaker-sql-execution        0.1.3
# amazon-sagemaker-sql-magic            0.1.1
# annotated-types                       0.6.0
# ansi2html                             0.0.0
# ansiwrap                              0.8.4
# antlr4-python3-runtime                4.9.3
# anyio                                 3.7.1
# archspec                              0.2.3
# ...
