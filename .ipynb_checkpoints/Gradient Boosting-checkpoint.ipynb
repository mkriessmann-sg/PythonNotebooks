# %% [markdown]
# # Gradient Boosting sample code
#
# copy of gradient boosting [sample code](https://qiita.com/predora005/items/19aebcf3aa05946c7cf4)

# %% [markdown]
# ## How to use XGBoost: multi class classification using iris data
#
# XGBoost is a library using a type of decision tree algorythm, the GBDT(Gradient boosted decision tree).
# This is a guide on the installation and use of said library.
# While multiple programming languages can be used, this guide will show the use with Python.

# %% [markdown]
# ## What is GBDT
# - a type of decision tree model
# - a gradient boosted desicion tree
#
# Another famous decision tree model is the random forest, which is summarized in the article below.
# https://qiita.com/_tsuru/items/23fdc43ee0e54ec7c87e

# %% [markdown]
# ## The hallmarks of GBDT
# - easily achievable accuracy
# - can use loss function values
# - can handle numeric data
#
# Since it has a easily achievable accuracy, it's popular in the machine learning competition Kaggle.

# %% [markdown]
# ## [1] How to use
#
# We will be using the iris data set from scikit-learn. The OS used is Amazon Linux2.

# %% [markdown]
# ## [1-1] Installation
#
# In Amazon Linux2 the installation is as follows. A guide on the installation can be found on the official website.
# https://xgboost.readthedocs.io/en/latest/build.html
#
# Comment:
# type `pip3 install xgboost` into the responsible CLI.

# %% [markdown]
# ## [1-2] Import

# %%
import xgboost as xgb

# %% [markdown]
# ## [1-3] Retrieve the Iris data
#
# There are no particularities to this process. You retrieve the Iris data and create a pandas DataFrame and a Series.
#
#
# Comment:
# iris data represents the input variables, meaning the features the flower has to be able to be classified.
# iris target represents the output variables, meaning what kind of flower it is, encoded as integer.
# Basically, data is the question, target is the answer

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()

iris_data = pd.DataFrame(iris.data, columns = iris.feature_names)
iris_target = pd.Series(iris.target)

# %% [markdown]
# ## [1-4] Create training and testing data sets
#
# There are no particularities here either, `train_test_split` from the scikit-learn package is used to split the data into training and testing data sets.

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(iris_data, iris_target, test_size = 0.2, shuffle = True)

# %% [markdown]
# ## [1-5] Convert the data into an XGBoost data type
#
# XGBoost uses `DMatrix` data types.
#
# `DMatrix` is made up of numpy `ndarray` and pandas `DataFrame` data types, which should not pose a problem.
#
# Details on what type of data can be used can be found in the official documentation below.
# https://xgboost.readthedocs.io/en/latest/python/python_intro.html#data-interface

# %%
dtrain = xgb.DMatrix(train_x, label = train_y)

# %% [markdown]
# ## [1-6] Set Parameters
#
# Set each specific parameter.

# %%
param = {'max_depth' : 2, 'eta' : 1, 'objective': 'multi:softmax', 'num_class': 3}

# %% [markdown]
# The meaning of each parameter is as follows:
# - max_depth = how many trees will be made at a maximum
# - eta = learning rate, conrols the step size at each iteration. small nummber prevents overfitting, but requires more boosting rounds
# - objective = specifies the learning task and the corresponding learning objective
# - num_class = the number of classes
#
# The learning objective described here is "multi:softmax." To learn more about this, check the official documentation.
# https://xgboost.readthedocs.io/en/latest/parameter.html

# %% [markdown]
# ## [1-7] Training
#
# `num_round` represents the number of training rounds.

# %%
num_round = 10
bst = xgb.train(param,dtrain, num_round)

# %% [markdown]
# ## [1-8] Prediction

# %%
dtest = xgb.DMatrix(test_x)
pred = bst.predict(dtest)

# %% [markdown]
# ## [1-9] Confirming Accuaracy
#
# Confirm the accuary with scikit's `accuacy_score`.

# %%
from sklearn.metrics import accuracy_score

score = accuracy_score(test_y, pred)
print('score:{0:.4f}'.format(score))
# 0.9667
# Out:
# score:0.9667

# %% [markdown]
# ## [1-10] Plot the importance
#
# Visualize which features have contributed in what way to the predicted result.

# %%
xgb.plot_importance(bst)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ## [2] Validation and early stopping during training
#
# Validation and early stopping during the training proccess is easily accomplished by utilizing the validation data.

# %% [markdown]
# ## [2-1] Splitting the data
#
# A part of the training data is used for validation.

# %%
train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=0.2, shuffle=True)

# %% [markdown]
# ## [2-2] Creating the DMatrix

# %%
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(valid_x, label=valid_y)

# %% [markdown]
# ## [2-3] Add parameters
#
# When using validation, the "eval_metric" has to be added to the parameters. "eval_metric" defines how the result is evaluated.

# %%
param = {'max_depth': 2, 'eta': 0.5, 'objective': 'multi:softmax', 'num_class': 3, 'eval_metric': 'mlogloss'}

# %% [markdown]
# ## [2-4] Training
#
# The data to be observed is defined in "evallist." The label for the validation data is 'eval,'  for the training data 'train.'
#
# xgb.train now has the addtional parameter `early_stopping_rounds`. If the evaluation has not changed after 5 rounds, the training proccess will be cancelled an the model output.

# %%
evallist = [(dvalid, 'eval'), (dtrain, 'train')];
num_round = 10000;
bst = xgb.train(param, dtrain, num_round, evals = evallist, early_stopping_rounds=5);


# [0]   eval-mlogloss:0.61103   train-mlogloss:0.60698
# Multiple eval metrics have been passed: 'train-mlogloss' will be used for early stopping.
# 
# Will train until train-mlogloss hasn't improved in 5 rounds.
# [1]   eval-mlogloss:0.36291   train-mlogloss:0.35779
# [2]   eval-mlogloss:0.22432   train-mlogloss:0.23488
# 
# 〜〜〜 途中省略 〜〜〜
# 
# Stopping. Best iteration:
# [1153]    eval-mlogloss:0.00827   train-mlogloss:0.01863
# Out:
# [0]	eval-mlogloss:0.60933	train-mlogloss:0.57233
# [1]	eval-mlogloss:0.40969	train-mlogloss:0.35679
# [2]	eval-mlogloss:0.29594	train-mlogloss:0.24266
# [3]	eval-mlogloss:0.24550	train-mlogloss:0.17689
# [4]	eval-mlogloss:0.20681	train-mlogloss:0.13395
# [5]	eval-mlogloss:0.19718	train-mlogloss:0.10766
# [6]	eval-mlogloss:0.17885	train-mlogloss:0.08982
# [7]	eval-mlogloss:0.18053	train-mlogloss:0.07422
# [8]	eval-mlogloss:0.18688	train-mlogloss:0.06468
# [9]	eval-mlogloss:0.18016	train-mlogloss:0.05746
# [10]	eval-mlogloss:0.18478	train-mlogloss:0.05110
# [11]	eval-mlogloss:0.19241	train-mlogloss:0.04619
# [12]	eval-mlogloss:0.19593	train-mlogloss:0.04308
# [13]	eval-mlogloss:0.20384	train-mlogloss:0.04044
# [14]	eval-mlogloss:0.20085	train-mlogloss:0.03867
# [15]	eval-mlogloss:0.20514	train-mlogloss:0.03732
# [16]	eval-mlogloss:0.21160	train-mlogloss:0.03596
# [17]	eval-mlogloss:0.21773	train-mlogloss:0.03405
# [18]	eval-mlogloss:0.21700	train-mlogloss:0.03289
# [19]	eval-mlogloss:0.22074	train-mlogloss:0.03213
# [20]	eval-mlogloss:0.22592	train-mlogloss:0.03113
# [21]	eval-mlogloss:0.22761	train-mlogloss:0.03044
# [22]	eval-mlogloss:0.22537	train-mlogloss:0.02986
# [23]	eval-mlogloss:0.23269	train-mlogloss:0.02920
# [24]	eval-mlogloss:0.23439	train-mlogloss:0.02865
# [25]	eval-mlogloss:0.23877	train-mlogloss:0.02809
# [26]	eval-mlogloss:0.23976	train-mlogloss:0.02752
# [27]	eval-mlogloss:0.23941	train-mlogloss:0.02708
# [28]	eval-mlogloss:0.24268	train-mlogloss:0.02657
# [29]	eval-mlogloss:0.24391	train-mlogloss:0.02613
# [30]	eval-mlogloss:0.24679	train-mlogloss:0.02572
# [31]	eval-mlogloss:0.24628	train-mlogloss:0.02524
# [32]	eval-mlogloss:0.25265	train-mlogloss:0.02484
# [33]	eval-mlogloss:0.25413	train-mlogloss:0.02442
# [34]	eval-mlogloss:0.25164	train-mlogloss:0.02406
# [35]	eval-mlogloss:0.25405	train-mlogloss:0.02371
# [36]	eval-mlogloss:0.25310	train-mlogloss:0.02343
# [37]	eval-mlogloss:0.25718	train-mlogloss:0.02306
# [38]	eval-mlogloss:0.26121	train-mlogloss:0.02280
# [39]	eval-mlogloss:0.26016	train-mlogloss:0.02257
# [40]	eval-mlogloss:0.26339	train-mlogloss:0.02235
# [41]	eval-mlogloss:0.26214	train-mlogloss:0.02214
# [42]	eval-mlogloss:0.26575	train-mlogloss:0.02193
# [43]	eval-mlogloss:0.26451	train-mlogloss:0.02173
# [44]	eval-mlogloss:0.26763	train-mlogloss:0.02157
# [45]	eval-mlogloss:0.26570	train-mlogloss:0.02140
# [46]	eval-mlogloss:0.26938	train-mlogloss:0.02126
# [47]	eval-mlogloss:0.27040	train-mlogloss:0.02109
# [48]	eval-mlogloss:0.26864	train-mlogloss:0.02097
# [49]	eval-mlogloss:0.27232	train-mlogloss:0.02083
# [50]	eval-mlogloss:0.27338	train-mlogloss:0.02071
# [51]	eval-mlogloss:0.27401	train-mlogloss:0.02059
# [52]	eval-mlogloss:0.27502	train-mlogloss:0.02048
# [53]	eval-mlogloss:0.27563	train-mlogloss:0.02037
# [54]	eval-mlogloss:0.27425	train-mlogloss:0.02027
# [55]	eval-mlogloss:0.27757	train-mlogloss:0.02017
# [56]	eval-mlogloss:0.27614	train-mlogloss:0.02008
# [57]	eval-mlogloss:0.27932	train-mlogloss:0.01998
# [58]	eval-mlogloss:0.27981	train-mlogloss:0.01990
# [59]	eval-mlogloss:0.28083	train-mlogloss:0.01981
# [60]	eval-mlogloss:0.28130	train-mlogloss:0.01973
# [61]	eval-mlogloss:0.28226	train-mlogloss:0.01965
# [62]	eval-mlogloss:0.28272	train-mlogloss:0.01957
# [63]	eval-mlogloss:0.28364	train-mlogloss:0.01950
# [64]	eval-mlogloss:0.28410	train-mlogloss:0.01943
# [65]	eval-mlogloss:0.28295	train-mlogloss:0.01936
# [66]	eval-mlogloss:0.28578	train-mlogloss:0.01929
# [67]	eval-mlogloss:0.28459	train-mlogloss:0.01923
# [68]	eval-mlogloss:0.28731	train-mlogloss:0.01917
# [69]	eval-mlogloss:0.28769	train-mlogloss:0.01911
# [70]	eval-mlogloss:0.28862	train-mlogloss:0.01905
# [71]	eval-mlogloss:0.28899	train-mlogloss:0.01899
# [72]	eval-mlogloss:0.28987	train-mlogloss:0.01894
# [73]	eval-mlogloss:0.29024	train-mlogloss:0.01889
# [74]	eval-mlogloss:0.29108	train-mlogloss:0.01884
# [75]	eval-mlogloss:0.29145	train-mlogloss:0.01879
# [76]	eval-mlogloss:0.29138	train-mlogloss:0.01874
# [77]	eval-mlogloss:0.28907	train-mlogloss:0.01870
# [78]	eval-mlogloss:0.28996	train-mlogloss:0.01867
# [79]	eval-mlogloss:0.28885	train-mlogloss:0.01863
# [80]	eval-mlogloss:0.28956	train-mlogloss:0.01860
# [81]	eval-mlogloss:0.28850	train-mlogloss:0.01857
# [82]	eval-mlogloss:0.28750	train-mlogloss:0.01854
# [83]	eval-mlogloss:0.28750	train-mlogloss:0.01851
# [84]	eval-mlogloss:0.28751	train-mlogloss:0.01848
# [85]	eval-mlogloss:0.28825	train-mlogloss:0.01846
# [86]	eval-mlogloss:0.28900	train-mlogloss:0.01843
# [87]	eval-mlogloss:0.28813	train-mlogloss:0.01840
# [88]	eval-mlogloss:0.28883	train-mlogloss:0.01838
# [89]	eval-mlogloss:0.28883	train-mlogloss:0.01835
# [90]	eval-mlogloss:0.28794	train-mlogloss:0.01833
# [91]	eval-mlogloss:0.28800	train-mlogloss:0.01831
# [92]	eval-mlogloss:0.28804	train-mlogloss:0.01829
# [93]	eval-mlogloss:0.28876	train-mlogloss:0.01826
# [94]	eval-mlogloss:0.28880	train-mlogloss:0.01824
# [95]	eval-mlogloss:0.28874	train-mlogloss:0.01822
# [96]	eval-mlogloss:0.28883	train-mlogloss:0.01820
# [97]	eval-mlogloss:0.28886	train-mlogloss:0.01818
# [98]	eval-mlogloss:0.28888	train-mlogloss:0.01816
# [99]	eval-mlogloss:0.28956	train-mlogloss:0.01814
# [100]	eval-mlogloss:0.28950	train-mlogloss:0.01812
# [101]	eval-mlogloss:0.28887	train-mlogloss:0.01810
# [102]	eval-mlogloss:0.28958	train-mlogloss:0.01808
# [103]	eval-mlogloss:0.28952	train-mlogloss:0.01807
# [104]	eval-mlogloss:0.28972	train-mlogloss:0.01805
# [105]	eval-mlogloss:0.28975	train-mlogloss:0.01803
# [106]	eval-mlogloss:0.29043	train-mlogloss:0.01801
# [107]	eval-mlogloss:0.29037	train-mlogloss:0.01800
# [108]	eval-mlogloss:0.28986	train-mlogloss:0.01798
# [109]	eval-mlogloss:0.29055	train-mlogloss:0.01796
# [110]	eval-mlogloss:0.29049	train-mlogloss:0.01794
# [111]	eval-mlogloss:0.29077	train-mlogloss:0.01793
# [112]	eval-mlogloss:0.29080	train-mlogloss:0.01791
# [113]	eval-mlogloss:0.29074	train-mlogloss:0.01790
# [114]	eval-mlogloss:0.29107	train-mlogloss:0.01788
# [115]	eval-mlogloss:0.29109	train-mlogloss:0.01786
# [116]	eval-mlogloss:0.29175	train-mlogloss:0.01785
# [117]	eval-mlogloss:0.29169	train-mlogloss:0.01783
# [118]	eval-mlogloss:0.29171	train-mlogloss:0.01782
# [119]	eval-mlogloss:0.29240	train-mlogloss:0.01780
# [120]	eval-mlogloss:0.29243	train-mlogloss:0.01779
# [121]	eval-mlogloss:0.29237	train-mlogloss:0.01778
# [122]	eval-mlogloss:0.29268	train-mlogloss:0.01776
# [123]	eval-mlogloss:0.29269	train-mlogloss:0.01775
# [124]	eval-mlogloss:0.29227	train-mlogloss:0.01774
# [125]	eval-mlogloss:0.29221	train-mlogloss:0.01772
# [126]	eval-mlogloss:0.29256	train-mlogloss:0.01771
# [127]	eval-mlogloss:0.29181	train-mlogloss:0.01769
# [128]	eval-mlogloss:0.29186	train-mlogloss:0.01768
# [129]	eval-mlogloss:0.29195	train-mlogloss:0.01767
# [130]	eval-mlogloss:0.29192	train-mlogloss:0.01766
# [131]	eval-mlogloss:0.29269	train-mlogloss:0.01764
# [132]	eval-mlogloss:0.29339	train-mlogloss:0.01763
# [133]	eval-mlogloss:0.29336	train-mlogloss:0.01762
# [134]	eval-mlogloss:0.29373	train-mlogloss:0.01760
# [135]	eval-mlogloss:0.29376	train-mlogloss:0.01759
# [136]	eval-mlogloss:0.29340	train-mlogloss:0.01758
# [137]	eval-mlogloss:0.29336	train-mlogloss:0.01756
# [138]	eval-mlogloss:0.29373	train-mlogloss:0.01755
# [139]	eval-mlogloss:0.29298	train-mlogloss:0.01754
# [140]	eval-mlogloss:0.29305	train-mlogloss:0.01752
# [141]	eval-mlogloss:0.29313	train-mlogloss:0.01751
# [142]	eval-mlogloss:0.29311	train-mlogloss:0.01750
# [143]	eval-mlogloss:0.29354	train-mlogloss:0.01749
# [144]	eval-mlogloss:0.29358	train-mlogloss:0.01748
# [145]	eval-mlogloss:0.29283	train-mlogloss:0.01746
# [146]	eval-mlogloss:0.29291	train-mlogloss:0.01745
# [147]	eval-mlogloss:0.29366	train-mlogloss:0.01744
# [148]	eval-mlogloss:0.29366	train-mlogloss:0.01743
# [149]	eval-mlogloss:0.29408	train-mlogloss:0.01741
# [150]	eval-mlogloss:0.29406	train-mlogloss:0.01740
# [151]	eval-mlogloss:0.29380	train-mlogloss:0.01739
# [152]	eval-mlogloss:0.29382	train-mlogloss:0.01738
# [153]	eval-mlogloss:0.29455	train-mlogloss:0.01737
# [154]	eval-mlogloss:0.29452	train-mlogloss:0.01735
# [155]	eval-mlogloss:0.29493	train-mlogloss:0.01734
# [156]	eval-mlogloss:0.29497	train-mlogloss:0.01733
# [157]	eval-mlogloss:0.29418	train-mlogloss:0.01732
# [158]	eval-mlogloss:0.29426	train-mlogloss:0.01731
# [159]	eval-mlogloss:0.29434	train-mlogloss:0.01729
# [160]	eval-mlogloss:0.29432	train-mlogloss:0.01728
# [161]	eval-mlogloss:0.29477	train-mlogloss:0.01727
# [162]	eval-mlogloss:0.29474	train-mlogloss:0.01726
# [163]	eval-mlogloss:0.29521	train-mlogloss:0.01725
# [164]	eval-mlogloss:0.29525	train-mlogloss:0.01724
# [165]	eval-mlogloss:0.29447	train-mlogloss:0.01722
# [166]	eval-mlogloss:0.29456	train-mlogloss:0.01721
# [167]	eval-mlogloss:0.29530	train-mlogloss:0.01720
# [168]	eval-mlogloss:0.29530	train-mlogloss:0.01719
# [169]	eval-mlogloss:0.29574	train-mlogloss:0.01718
# [170]	eval-mlogloss:0.29573	train-mlogloss:0.01717
# [171]	eval-mlogloss:0.29548	train-mlogloss:0.01716
# [172]	eval-mlogloss:0.29551	train-mlogloss:0.01715
# [173]	eval-mlogloss:0.29472	train-mlogloss:0.01713
# [174]	eval-mlogloss:0.29480	train-mlogloss:0.01712
# [175]	eval-mlogloss:0.29555	train-mlogloss:0.01711
# [176]	eval-mlogloss:0.29556	train-mlogloss:0.01710
# [177]	eval-mlogloss:0.29602	train-mlogloss:0.01709
# [178]	eval-mlogloss:0.29608	train-mlogloss:0.01708
# [179]	eval-mlogloss:0.29532	train-mlogloss:0.01707
# [180]	eval-mlogloss:0.29542	train-mlogloss:0.01706
# [181]	eval-mlogloss:0.29545	train-mlogloss:0.01704
# [182]	eval-mlogloss:0.29622	train-mlogloss:0.01703
# [183]	eval-mlogloss:0.29628	train-mlogloss:0.01702
# [184]	eval-mlogloss:0.29553	train-mlogloss:0.01701
# [185]	eval-mlogloss:0.29564	train-mlogloss:0.01700
# [186]	eval-mlogloss:0.29571	train-mlogloss:0.01699
# [187]	eval-mlogloss:0.29571	train-mlogloss:0.01698
# [188]	eval-mlogloss:0.29645	train-mlogloss:0.01697
# [189]	eval-mlogloss:0.29650	train-mlogloss:0.01696
# [190]	eval-mlogloss:0.29576	train-mlogloss:0.01695
# [191]	eval-mlogloss:0.29585	train-mlogloss:0.01694
# [192]	eval-mlogloss:0.29587	train-mlogloss:0.01693
# [193]	eval-mlogloss:0.29665	train-mlogloss:0.01692
# [194]	eval-mlogloss:0.29671	train-mlogloss:0.01691
# [195]	eval-mlogloss:0.29598	train-mlogloss:0.01690
# [196]	eval-mlogloss:0.29607	train-mlogloss:0.01689
# [197]	eval-mlogloss:0.29681	train-mlogloss:0.01688
# [198]	eval-mlogloss:0.29683	train-mlogloss:0.01686
# [199]	eval-mlogloss:0.29756	train-mlogloss:0.01685
# [200]	eval-mlogloss:0.29755	train-mlogloss:0.01684
# [201]	eval-mlogloss:0.29827	train-mlogloss:0.01683
# [202]	eval-mlogloss:0.29833	train-mlogloss:0.01682
# [203]	eval-mlogloss:0.29761	train-mlogloss:0.01681
# [204]	eval-mlogloss:0.29770	train-mlogloss:0.01680
# [205]	eval-mlogloss:0.29776	train-mlogloss:0.01679
# [206]	eval-mlogloss:0.29777	train-mlogloss:0.01678
# [207]	eval-mlogloss:0.29848	train-mlogloss:0.01677
# [208]	eval-mlogloss:0.29847	train-mlogloss:0.01676
# [209]	eval-mlogloss:0.29918	train-mlogloss:0.01675
# [210]	eval-mlogloss:0.29923	train-mlogloss:0.01674
# [211]	eval-mlogloss:0.29850	train-mlogloss:0.01673
# [212]	eval-mlogloss:0.29859	train-mlogloss:0.01672
# [213]	eval-mlogloss:0.29865	train-mlogloss:0.01671
# [214]	eval-mlogloss:0.29865	train-mlogloss:0.01670
# [215]	eval-mlogloss:0.29936	train-mlogloss:0.01669
# [216]	eval-mlogloss:0.29936	train-mlogloss:0.01668
# [217]	eval-mlogloss:0.30006	train-mlogloss:0.01667
# [218]	eval-mlogloss:0.30012	train-mlogloss:0.01666
# [219]	eval-mlogloss:0.29936	train-mlogloss:0.01665
# [220]	eval-mlogloss:0.29946	train-mlogloss:0.01665
# [221]	eval-mlogloss:0.30015	train-mlogloss:0.01664
# [222]	eval-mlogloss:0.30018	train-mlogloss:0.01663
# [223]	eval-mlogloss:0.30087	train-mlogloss:0.01662
# [224]	eval-mlogloss:0.30087	train-mlogloss:0.01661
# [225]	eval-mlogloss:0.30156	train-mlogloss:0.01660
# [226]	eval-mlogloss:0.30162	train-mlogloss:0.01659
# [227]	eval-mlogloss:0.30088	train-mlogloss:0.01658
# [228]	eval-mlogloss:0.30098	train-mlogloss:0.01657
# [229]	eval-mlogloss:0.30103	train-mlogloss:0.01656
# [230]	eval-mlogloss:0.30104	train-mlogloss:0.01655
# [231]	eval-mlogloss:0.30172	train-mlogloss:0.01654
# [232]	eval-mlogloss:0.30172	train-mlogloss:0.01653
# [233]	eval-mlogloss:0.30240	train-mlogloss:0.01652
# [234]	eval-mlogloss:0.30246	train-mlogloss:0.01651
# [235]	eval-mlogloss:0.30170	train-mlogloss:0.01650
# [236]	eval-mlogloss:0.30180	train-mlogloss:0.01650
# [237]	eval-mlogloss:0.30113	train-mlogloss:0.01649
# [238]	eval-mlogloss:0.30125	train-mlogloss:0.01648
# [239]	eval-mlogloss:0.30129	train-mlogloss:0.01647
# [240]	eval-mlogloss:0.30202	train-mlogloss:0.01646
# [241]	eval-mlogloss:0.30210	train-mlogloss:0.01645
# [242]	eval-mlogloss:0.30141	train-mlogloss:0.01644
# [243]	eval-mlogloss:0.30151	train-mlogloss:0.01643
# [244]	eval-mlogloss:0.30155	train-mlogloss:0.01643
# [245]	eval-mlogloss:0.30227	train-mlogloss:0.01642
# [246]	eval-mlogloss:0.30234	train-mlogloss:0.01641
# [247]	eval-mlogloss:0.30166	train-mlogloss:0.01640
# [248]	eval-mlogloss:0.30172	train-mlogloss:0.01639
# [249]	eval-mlogloss:0.30175	train-mlogloss:0.01638
# [250]	eval-mlogloss:0.30245	train-mlogloss:0.01637
# [251]	eval-mlogloss:0.30252	train-mlogloss:0.01636
# [252]	eval-mlogloss:0.30253	train-mlogloss:0.01636
# [253]	eval-mlogloss:0.30323	train-mlogloss:0.01635
# [254]	eval-mlogloss:0.30328	train-mlogloss:0.01634
# [255]	eval-mlogloss:0.30257	train-mlogloss:0.01633
# [256]	eval-mlogloss:0.30267	train-mlogloss:0.01632
# [257]	eval-mlogloss:0.30333	train-mlogloss:0.01631
# [258]	eval-mlogloss:0.30337	train-mlogloss:0.01630
# [259]	eval-mlogloss:0.30401	train-mlogloss:0.01630
# [260]	eval-mlogloss:0.30403	train-mlogloss:0.01629
# [261]	eval-mlogloss:0.30467	train-mlogloss:0.01628
# [262]	eval-mlogloss:0.30474	train-mlogloss:0.01627
# [263]	eval-mlogloss:0.30404	train-mlogloss:0.01626
# [264]	eval-mlogloss:0.30414	train-mlogloss:0.01625
# [265]	eval-mlogloss:0.30417	train-mlogloss:0.01625
# [266]	eval-mlogloss:0.30486	train-mlogloss:0.01624
# [267]	eval-mlogloss:0.30488	train-mlogloss:0.01623
# [268]	eval-mlogloss:0.30489	train-mlogloss:0.01622
# [269]	eval-mlogloss:0.30554	train-mlogloss:0.01621
# [270]	eval-mlogloss:0.30559	train-mlogloss:0.01621
# [271]	eval-mlogloss:0.30489	train-mlogloss:0.01620
# [272]	eval-mlogloss:0.30498	train-mlogloss:0.01619
# [273]	eval-mlogloss:0.30502	train-mlogloss:0.01618
# [274]	eval-mlogloss:0.30569	train-mlogloss:0.01617
# [275]	eval-mlogloss:0.30571	train-mlogloss:0.01617
# [276]	eval-mlogloss:0.30637	train-mlogloss:0.01616
# [277]	eval-mlogloss:0.30644	train-mlogloss:0.01615
# [278]	eval-mlogloss:0.30573	train-mlogloss:0.01614
# [279]	eval-mlogloss:0.30583	train-mlogloss:0.01613
# [280]	eval-mlogloss:0.30587	train-mlogloss:0.01613
# [281]	eval-mlogloss:0.30590	train-mlogloss:0.01612
# [282]	eval-mlogloss:0.30655	train-mlogloss:0.01611
# [283]	eval-mlogloss:0.30656	train-mlogloss:0.01610
# [284]	eval-mlogloss:0.30721	train-mlogloss:0.01609
# [285]	eval-mlogloss:0.30727	train-mlogloss:0.01609
# [286]	eval-mlogloss:0.30656	train-mlogloss:0.01608
# [287]	eval-mlogloss:0.30665	train-mlogloss:0.01607
# [288]	eval-mlogloss:0.30601	train-mlogloss:0.01606
# [289]	eval-mlogloss:0.30613	train-mlogloss:0.01606
# [290]	eval-mlogloss:0.30618	train-mlogloss:0.01605
# [291]	eval-mlogloss:0.30687	train-mlogloss:0.01604
# [292]	eval-mlogloss:0.30695	train-mlogloss:0.01603
# [293]	eval-mlogloss:0.30629	train-mlogloss:0.01602
# [294]	eval-mlogloss:0.30635	train-mlogloss:0.01602
# [295]	eval-mlogloss:0.30703	train-mlogloss:0.01601
# [296]	eval-mlogloss:0.30711	train-mlogloss:0.01600
# [297]	eval-mlogloss:0.30713	train-mlogloss:0.01600
# [298]	eval-mlogloss:0.30716	train-mlogloss:0.01599
# [299]	eval-mlogloss:0.30779	train-mlogloss:0.01598
# [300]	eval-mlogloss:0.30781	train-mlogloss:0.01597
# [301]	eval-mlogloss:0.30845	train-mlogloss:0.01597
# [302]	eval-mlogloss:0.30850	train-mlogloss:0.01596
# [303]	eval-mlogloss:0.30782	train-mlogloss:0.01595
# [304]	eval-mlogloss:0.30791	train-mlogloss:0.01594
# [305]	eval-mlogloss:0.30730	train-mlogloss:0.01594
# [306]	eval-mlogloss:0.30741	train-mlogloss:0.01593
# [307]	eval-mlogloss:0.30746	train-mlogloss:0.01592
# [308]	eval-mlogloss:0.30813	train-mlogloss:0.01591
# [309]	eval-mlogloss:0.30820	train-mlogloss:0.01591
# [310]	eval-mlogloss:0.30822	train-mlogloss:0.01590
# [311]	eval-mlogloss:0.30887	train-mlogloss:0.01589
# [312]	eval-mlogloss:0.30888	train-mlogloss:0.01589
# [313]	eval-mlogloss:0.30950	train-mlogloss:0.01588
# [314]	eval-mlogloss:0.30956	train-mlogloss:0.01587
# [315]	eval-mlogloss:0.30890	train-mlogloss:0.01587
# [316]	eval-mlogloss:0.30899	train-mlogloss:0.01586
# [317]	eval-mlogloss:0.30903	train-mlogloss:0.01585
# [318]	eval-mlogloss:0.30965	train-mlogloss:0.01584
# [319]	eval-mlogloss:0.30969	train-mlogloss:0.01584
# [320]	eval-mlogloss:0.30902	train-mlogloss:0.01583
# [321]	eval-mlogloss:0.30907	train-mlogloss:0.01583
# [322]	eval-mlogloss:0.30966	train-mlogloss:0.01582
# [323]	eval-mlogloss:0.30969	train-mlogloss:0.01581
# [324]	eval-mlogloss:0.31026	train-mlogloss:0.01581
# [325]	eval-mlogloss:0.31028	train-mlogloss:0.01580
# [326]	eval-mlogloss:0.31031	train-mlogloss:0.01579
# [327]	eval-mlogloss:0.30963	train-mlogloss:0.01579
# [328]	eval-mlogloss:0.30971	train-mlogloss:0.01578
# [329]	eval-mlogloss:0.30909	train-mlogloss:0.01578
# [330]	eval-mlogloss:0.30916	train-mlogloss:0.01577
# [331]	eval-mlogloss:0.30979	train-mlogloss:0.01576
# [332]	eval-mlogloss:0.30983	train-mlogloss:0.01576
# [333]	eval-mlogloss:0.31043	train-mlogloss:0.01575
# [334]	eval-mlogloss:0.31049	train-mlogloss:0.01574
# [335]	eval-mlogloss:0.31051	train-mlogloss:0.01574
# [336]	eval-mlogloss:0.31108	train-mlogloss:0.01573
# [337]	eval-mlogloss:0.31110	train-mlogloss:0.01573
# [338]	eval-mlogloss:0.31043	train-mlogloss:0.01572
# [339]	eval-mlogloss:0.31051	train-mlogloss:0.01571
# [340]	eval-mlogloss:0.31109	train-mlogloss:0.01571
# [341]	eval-mlogloss:0.31113	train-mlogloss:0.01570
# [342]	eval-mlogloss:0.31050	train-mlogloss:0.01570
# [343]	eval-mlogloss:0.31059	train-mlogloss:0.01569
# [344]	eval-mlogloss:0.31116	train-mlogloss:0.01569
# [345]	eval-mlogloss:0.31120	train-mlogloss:0.01568
# [346]	eval-mlogloss:0.31175	train-mlogloss:0.01567
# [347]	eval-mlogloss:0.31178	train-mlogloss:0.01567
# [348]	eval-mlogloss:0.31115	train-mlogloss:0.01566
# [349]	eval-mlogloss:0.31123	train-mlogloss:0.01566
# [350]	eval-mlogloss:0.31126	train-mlogloss:0.01565
# [351]	eval-mlogloss:0.31185	train-mlogloss:0.01564
# [352]	eval-mlogloss:0.31187	train-mlogloss:0.01564
# [353]	eval-mlogloss:0.31244	train-mlogloss:0.01563
# [354]	eval-mlogloss:0.31246	train-mlogloss:0.01563
# [355]	eval-mlogloss:0.31301	train-mlogloss:0.01562
# [356]	eval-mlogloss:0.31303	train-mlogloss:0.01562
# [357]	eval-mlogloss:0.31239	train-mlogloss:0.01561
# [358]	eval-mlogloss:0.31247	train-mlogloss:0.01561
# [359]	eval-mlogloss:0.31302	train-mlogloss:0.01560
# [360]	eval-mlogloss:0.31307	train-mlogloss:0.01560
# [361]	eval-mlogloss:0.31246	train-mlogloss:0.01559
# [362]	eval-mlogloss:0.31255	train-mlogloss:0.01558
# [363]	eval-mlogloss:0.31309	train-mlogloss:0.01558
# [364]	eval-mlogloss:0.31314	train-mlogloss:0.01557
# [365]	eval-mlogloss:0.31255	train-mlogloss:0.01557
# [366]	eval-mlogloss:0.31264	train-mlogloss:0.01556
# [367]	eval-mlogloss:0.31268	train-mlogloss:0.01556
# [368]	eval-mlogloss:0.31326	train-mlogloss:0.01555
# [369]	eval-mlogloss:0.31329	train-mlogloss:0.01555
# [370]	eval-mlogloss:0.31384	train-mlogloss:0.01554
# [371]	eval-mlogloss:0.31386	train-mlogloss:0.01554
# [372]	eval-mlogloss:0.31439	train-mlogloss:0.01553
# [373]	eval-mlogloss:0.31382	train-mlogloss:0.01553
# [374]	eval-mlogloss:0.31391	train-mlogloss:0.01552
# [375]	eval-mlogloss:0.31395	train-mlogloss:0.01552
# [376]	eval-mlogloss:0.31448	train-mlogloss:0.01551
# [377]	eval-mlogloss:0.31451	train-mlogloss:0.01551
# [378]	eval-mlogloss:0.31391	train-mlogloss:0.01550
# [379]	eval-mlogloss:0.31399	train-mlogloss:0.01550
# [380]	eval-mlogloss:0.31452	train-mlogloss:0.01549
# [381]	eval-mlogloss:0.31457	train-mlogloss:0.01549
# [382]	eval-mlogloss:0.31399	train-mlogloss:0.01548
# [383]	eval-mlogloss:0.31408	train-mlogloss:0.01548
# [384]	eval-mlogloss:0.31460	train-mlogloss:0.01547
# [385]	eval-mlogloss:0.31465	train-mlogloss:0.01547
# [386]	eval-mlogloss:0.31409	train-mlogloss:0.01546
# [387]	eval-mlogloss:0.31417	train-mlogloss:0.01546
# [388]	eval-mlogloss:0.31421	train-mlogloss:0.01545
# [389]	eval-mlogloss:0.31476	train-mlogloss:0.01545
# [390]	eval-mlogloss:0.31479	train-mlogloss:0.01544
# [391]	eval-mlogloss:0.31532	train-mlogloss:0.01544
# [392]	eval-mlogloss:0.31535	train-mlogloss:0.01543
# [393]	eval-mlogloss:0.31587	train-mlogloss:0.01543
# [394]	eval-mlogloss:0.31589	train-mlogloss:0.01542
# [395]	eval-mlogloss:0.31639	train-mlogloss:0.01542
# [396]	eval-mlogloss:0.31583	train-mlogloss:0.01542
# [397]	eval-mlogloss:0.31592	train-mlogloss:0.01541
# [398]	eval-mlogloss:0.31597	train-mlogloss:0.01541
# [399]	eval-mlogloss:0.31540	train-mlogloss:0.01540
# [400]	eval-mlogloss:0.31548	train-mlogloss:0.01540
# [401]	eval-mlogloss:0.31599	train-mlogloss:0.01539
# [402]	eval-mlogloss:0.31605	train-mlogloss:0.01539
# [403]	eval-mlogloss:0.31549	train-mlogloss:0.01538
# [404]	eval-mlogloss:0.31557	train-mlogloss:0.01538
# [405]	eval-mlogloss:0.31608	train-mlogloss:0.01537
# [406]	eval-mlogloss:0.31613	train-mlogloss:0.01537
# [407]	eval-mlogloss:0.31559	train-mlogloss:0.01537
# [408]	eval-mlogloss:0.31567	train-mlogloss:0.01536
# [409]	eval-mlogloss:0.31571	train-mlogloss:0.01536
# [410]	eval-mlogloss:0.31625	train-mlogloss:0.01535
# [411]	eval-mlogloss:0.31628	train-mlogloss:0.01535
# [412]	eval-mlogloss:0.31679	train-mlogloss:0.01534
# [413]	eval-mlogloss:0.31682	train-mlogloss:0.01534
# [414]	eval-mlogloss:0.31732	train-mlogloss:0.01533
# [415]	eval-mlogloss:0.31735	train-mlogloss:0.01533
# [416]	eval-mlogloss:0.31784	train-mlogloss:0.01533
# [417]	eval-mlogloss:0.31786	train-mlogloss:0.01532
# [418]	eval-mlogloss:0.31729	train-mlogloss:0.01532
# [419]	eval-mlogloss:0.31736	train-mlogloss:0.01531
# [420]	eval-mlogloss:0.31786	train-mlogloss:0.01531
# [421]	eval-mlogloss:0.31790	train-mlogloss:0.01530
# [422]	eval-mlogloss:0.31736	train-mlogloss:0.01530
# [423]	eval-mlogloss:0.31744	train-mlogloss:0.01530
# [424]	eval-mlogloss:0.31793	train-mlogloss:0.01529
# [425]	eval-mlogloss:0.31798	train-mlogloss:0.01529
# [426]	eval-mlogloss:0.31745	train-mlogloss:0.01528
# [427]	eval-mlogloss:0.31752	train-mlogloss:0.01528
# [428]	eval-mlogloss:0.31800	train-mlogloss:0.01528
# [429]	eval-mlogloss:0.31806	train-mlogloss:0.01527
# [430]	eval-mlogloss:0.31754	train-mlogloss:0.01527
# [431]	eval-mlogloss:0.31761	train-mlogloss:0.01526
# [432]	eval-mlogloss:0.31766	train-mlogloss:0.01526
# [433]	eval-mlogloss:0.31817	train-mlogloss:0.01526
# [434]	eval-mlogloss:0.31821	train-mlogloss:0.01525
# [435]	eval-mlogloss:0.31870	train-mlogloss:0.01525
# [436]	eval-mlogloss:0.31873	train-mlogloss:0.01524
# [437]	eval-mlogloss:0.31921	train-mlogloss:0.01524
# [438]	eval-mlogloss:0.31924	train-mlogloss:0.01524
# [439]	eval-mlogloss:0.31970	train-mlogloss:0.01523
# [440]	eval-mlogloss:0.31918	train-mlogloss:0.01523
# [441]	eval-mlogloss:0.31926	train-mlogloss:0.01522
# [442]	eval-mlogloss:0.31931	train-mlogloss:0.01522
# [443]	eval-mlogloss:0.31878	train-mlogloss:0.01522
# [444]	eval-mlogloss:0.31886	train-mlogloss:0.01521
# [445]	eval-mlogloss:0.31933	train-mlogloss:0.01521
# [446]	eval-mlogloss:0.31939	train-mlogloss:0.01520
# [447]	eval-mlogloss:0.31887	train-mlogloss:0.01520
# [448]	eval-mlogloss:0.31895	train-mlogloss:0.01520
# [449]	eval-mlogloss:0.31942	train-mlogloss:0.01519
# [450]	eval-mlogloss:0.31947	train-mlogloss:0.01519
# [451]	eval-mlogloss:0.31992	train-mlogloss:0.01519
# [452]	eval-mlogloss:0.31997	train-mlogloss:0.01518
# [453]	eval-mlogloss:0.31945	train-mlogloss:0.01518
# [454]	eval-mlogloss:0.31952	train-mlogloss:0.01517
# [455]	eval-mlogloss:0.31997	train-mlogloss:0.01517
# [456]	eval-mlogloss:0.32002	train-mlogloss:0.01517
# [457]	eval-mlogloss:0.31952	train-mlogloss:0.01516
# [458]	eval-mlogloss:0.31959	train-mlogloss:0.01516
# [459]	eval-mlogloss:0.31964	train-mlogloss:0.01516
# [460]	eval-mlogloss:0.32012	train-mlogloss:0.01515
# [461]	eval-mlogloss:0.32016	train-mlogloss:0.01515
# [462]	eval-mlogloss:0.32063	train-mlogloss:0.01514
# [463]	eval-mlogloss:0.32066	train-mlogloss:0.01514
# [464]	eval-mlogloss:0.32112	train-mlogloss:0.01514
# [465]	eval-mlogloss:0.32115	train-mlogloss:0.01513
# [466]	eval-mlogloss:0.32160	train-mlogloss:0.01513
# [467]	eval-mlogloss:0.32110	train-mlogloss:0.01513
# [468]	eval-mlogloss:0.32118	train-mlogloss:0.01512
# [469]	eval-mlogloss:0.32123	train-mlogloss:0.01512
# [470]	eval-mlogloss:0.32063	train-mlogloss:0.01512
# [471]	eval-mlogloss:0.32069	train-mlogloss:0.01511
# [472]	eval-mlogloss:0.32018	train-mlogloss:0.01511
# [473]	eval-mlogloss:0.32026	train-mlogloss:0.01511
# [474]	eval-mlogloss:0.31979	train-mlogloss:0.01510
# [475]	eval-mlogloss:0.31986	train-mlogloss:0.01510
# [476]	eval-mlogloss:0.32035	train-mlogloss:0.01510
# [477]	eval-mlogloss:0.32041	train-mlogloss:0.01509
# [478]	eval-mlogloss:0.32088	train-mlogloss:0.01509
# [479]	eval-mlogloss:0.32092	train-mlogloss:0.01509
# [480]	eval-mlogloss:0.32138	train-mlogloss:0.01508
# [481]	eval-mlogloss:0.32142	train-mlogloss:0.01508
# [482]	eval-mlogloss:0.32186	train-mlogloss:0.01508
# [483]	eval-mlogloss:0.32191	train-mlogloss:0.01507
# [484]	eval-mlogloss:0.32131	train-mlogloss:0.01507
# [485]	eval-mlogloss:0.32135	train-mlogloss:0.01506
# [486]	eval-mlogloss:0.32178	train-mlogloss:0.01506
# [487]	eval-mlogloss:0.32182	train-mlogloss:0.01506
# [488]	eval-mlogloss:0.32225	train-mlogloss:0.01505
# [489]	eval-mlogloss:0.32228	train-mlogloss:0.01505
# [490]	eval-mlogloss:0.32231	train-mlogloss:0.01505
# [491]	eval-mlogloss:0.32178	train-mlogloss:0.01504
# [492]	eval-mlogloss:0.32184	train-mlogloss:0.01504
# [493]	eval-mlogloss:0.32124	train-mlogloss:0.01504
# [494]	eval-mlogloss:0.32168	train-mlogloss:0.01503
# [495]	eval-mlogloss:0.32174	train-mlogloss:0.01503
# [496]	eval-mlogloss:0.32216	train-mlogloss:0.01503
# [497]	eval-mlogloss:0.32221	train-mlogloss:0.01502
# [498]	eval-mlogloss:0.32224	train-mlogloss:0.01502
# [499]	eval-mlogloss:0.32172	train-mlogloss:0.01502
# [500]	eval-mlogloss:0.32178	train-mlogloss:0.01501
# [501]	eval-mlogloss:0.32121	train-mlogloss:0.01501
# [502]	eval-mlogloss:0.32126	train-mlogloss:0.01501
# [503]	eval-mlogloss:0.32172	train-mlogloss:0.01500
# [504]	eval-mlogloss:0.32176	train-mlogloss:0.01500
# [505]	eval-mlogloss:0.32221	train-mlogloss:0.01500
# [506]	eval-mlogloss:0.32224	train-mlogloss:0.01499
# [507]	eval-mlogloss:0.32268	train-mlogloss:0.01499
# [508]	eval-mlogloss:0.32271	train-mlogloss:0.01499
# [509]	eval-mlogloss:0.32314	train-mlogloss:0.01499
# [510]	eval-mlogloss:0.32318	train-mlogloss:0.01498
# [511]	eval-mlogloss:0.32267	train-mlogloss:0.01498
# [512]	eval-mlogloss:0.32273	train-mlogloss:0.01498
# [513]	eval-mlogloss:0.32316	train-mlogloss:0.01497
# [514]	eval-mlogloss:0.32321	train-mlogloss:0.01497
# [515]	eval-mlogloss:0.32265	train-mlogloss:0.01497
# [516]	eval-mlogloss:0.32270	train-mlogloss:0.01496
# [517]	eval-mlogloss:0.32223	train-mlogloss:0.01496
# [518]	eval-mlogloss:0.32230	train-mlogloss:0.01496
# [519]	eval-mlogloss:0.32177	train-mlogloss:0.01495
# [520]	eval-mlogloss:0.32183	train-mlogloss:0.01495
# [521]	eval-mlogloss:0.32137	train-mlogloss:0.01495
# [522]	eval-mlogloss:0.32144	train-mlogloss:0.01494
# [523]	eval-mlogloss:0.32190	train-mlogloss:0.01494
# [524]	eval-mlogloss:0.32195	train-mlogloss:0.01494
# [525]	eval-mlogloss:0.32240	train-mlogloss:0.01493
# [526]	eval-mlogloss:0.32244	train-mlogloss:0.01493
# [527]	eval-mlogloss:0.32287	train-mlogloss:0.01493
# [528]	eval-mlogloss:0.32292	train-mlogloss:0.01492
# [529]	eval-mlogloss:0.32237	train-mlogloss:0.01492
# [530]	eval-mlogloss:0.32241	train-mlogloss:0.01492
# [531]	eval-mlogloss:0.32283	train-mlogloss:0.01491
# [532]	eval-mlogloss:0.32287	train-mlogloss:0.01491
# [533]	eval-mlogloss:0.32328	train-mlogloss:0.01491
# [534]	eval-mlogloss:0.32332	train-mlogloss:0.01491
# [535]	eval-mlogloss:0.32373	train-mlogloss:0.01490
# [536]	eval-mlogloss:0.32376	train-mlogloss:0.01490
# [537]	eval-mlogloss:0.32416	train-mlogloss:0.01490
# [538]	eval-mlogloss:0.32420	train-mlogloss:0.01489
# [539]	eval-mlogloss:0.32459	train-mlogloss:0.01489
# [540]	eval-mlogloss:0.32463	train-mlogloss:0.01489
# [541]	eval-mlogloss:0.32415	train-mlogloss:0.01489
# [542]	eval-mlogloss:0.32457	train-mlogloss:0.01488
# [543]	eval-mlogloss:0.32462	train-mlogloss:0.01488
# [544]	eval-mlogloss:0.32502	train-mlogloss:0.01488
# [545]	eval-mlogloss:0.32507	train-mlogloss:0.01487
# [546]	eval-mlogloss:0.32546	train-mlogloss:0.01487
# [547]	eval-mlogloss:0.32550	train-mlogloss:0.01487
# [548]	eval-mlogloss:0.32588	train-mlogloss:0.01487
# [549]	eval-mlogloss:0.32592	train-mlogloss:0.01486
# [550]	eval-mlogloss:0.32630	train-mlogloss:0.01486
# [551]	eval-mlogloss:0.32634	train-mlogloss:0.01486
# [552]	eval-mlogloss:0.32671	train-mlogloss:0.01486
# [553]	eval-mlogloss:0.32675	train-mlogloss:0.01485
# [554]	eval-mlogloss:0.32712	train-mlogloss:0.01485
# [555]	eval-mlogloss:0.32715	train-mlogloss:0.01485
# [556]	eval-mlogloss:0.32671	train-mlogloss:0.01485
# [557]	eval-mlogloss:0.32678	train-mlogloss:0.01484
# [558]	eval-mlogloss:0.32635	train-mlogloss:0.01484
# [559]	eval-mlogloss:0.32643	train-mlogloss:0.01483
# [560]	eval-mlogloss:0.32600	train-mlogloss:0.01483
# [561]	eval-mlogloss:0.32607	train-mlogloss:0.01483
# [562]	eval-mlogloss:0.32650	train-mlogloss:0.01483
# [563]	eval-mlogloss:0.32655	train-mlogloss:0.01482
# [564]	eval-mlogloss:0.32695	train-mlogloss:0.01482
# [565]	eval-mlogloss:0.32700	train-mlogloss:0.01482
# [566]	eval-mlogloss:0.32739	train-mlogloss:0.01482
# [567]	eval-mlogloss:0.32743	train-mlogloss:0.01481
# [568]	eval-mlogloss:0.32781	train-mlogloss:0.01481
# [569]	eval-mlogloss:0.32785	train-mlogloss:0.01481
# [570]	eval-mlogloss:0.32822	train-mlogloss:0.01481
# [571]	eval-mlogloss:0.32826	train-mlogloss:0.01480
# [572]	eval-mlogloss:0.32862	train-mlogloss:0.01480
# [573]	eval-mlogloss:0.32866	train-mlogloss:0.01480
# [574]	eval-mlogloss:0.32902	train-mlogloss:0.01480
# [575]	eval-mlogloss:0.32906	train-mlogloss:0.01479
# [576]	eval-mlogloss:0.32910	train-mlogloss:0.01479
# [577]	eval-mlogloss:0.32861	train-mlogloss:0.01479
# [578]	eval-mlogloss:0.32821	train-mlogloss:0.01478
# [579]	eval-mlogloss:0.32830	train-mlogloss:0.01478
# [580]	eval-mlogloss:0.32790	train-mlogloss:0.01478
# [581]	eval-mlogloss:0.32829	train-mlogloss:0.01478
# [582]	eval-mlogloss:0.32836	train-mlogloss:0.01477
# [583]	eval-mlogloss:0.32873	train-mlogloss:0.01477
# [584]	eval-mlogloss:0.32878	train-mlogloss:0.01477
# [585]	eval-mlogloss:0.32914	train-mlogloss:0.01477
# [586]	eval-mlogloss:0.32918	train-mlogloss:0.01476
# [587]	eval-mlogloss:0.32953	train-mlogloss:0.01476
# [588]	eval-mlogloss:0.32957	train-mlogloss:0.01476
# [589]	eval-mlogloss:0.32991	train-mlogloss:0.01476
# [590]	eval-mlogloss:0.32995	train-mlogloss:0.01476
# [591]	eval-mlogloss:0.33000	train-mlogloss:0.01475
# [592]	eval-mlogloss:0.32953	train-mlogloss:0.01475
# [593]	eval-mlogloss:0.32989	train-mlogloss:0.01475
# [594]	eval-mlogloss:0.32995	train-mlogloss:0.01474
# [595]	eval-mlogloss:0.32956	train-mlogloss:0.01474
# [596]	eval-mlogloss:0.32964	train-mlogloss:0.01474
# [597]	eval-mlogloss:0.32924	train-mlogloss:0.01473
# [598]	eval-mlogloss:0.32930	train-mlogloss:0.01473
# [599]	eval-mlogloss:0.32969	train-mlogloss:0.01473
# [600]	eval-mlogloss:0.32974	train-mlogloss:0.01473
# [601]	eval-mlogloss:0.33012	train-mlogloss:0.01473
# [602]	eval-mlogloss:0.33016	train-mlogloss:0.01472
# [603]	eval-mlogloss:0.33052	train-mlogloss:0.01472
# [604]	eval-mlogloss:0.33056	train-mlogloss:0.01472
# [605]	eval-mlogloss:0.33091	train-mlogloss:0.01472
# [606]	eval-mlogloss:0.33095	train-mlogloss:0.01472
# [607]	eval-mlogloss:0.33130	train-mlogloss:0.01471
# [608]	eval-mlogloss:0.33133	train-mlogloss:0.01471
# [609]	eval-mlogloss:0.33138	train-mlogloss:0.01471
# [610]	eval-mlogloss:0.33093	train-mlogloss:0.01470
# [611]	eval-mlogloss:0.33129	train-mlogloss:0.01470
# [612]	eval-mlogloss:0.33134	train-mlogloss:0.01470
# [613]	eval-mlogloss:0.33169	train-mlogloss:0.01470
# [614]	eval-mlogloss:0.33173	train-mlogloss:0.01470
# [615]	eval-mlogloss:0.33207	train-mlogloss:0.01469
# [616]	eval-mlogloss:0.33211	train-mlogloss:0.01469
# [617]	eval-mlogloss:0.33171	train-mlogloss:0.01469
# [618]	eval-mlogloss:0.33179	train-mlogloss:0.01469
# [619]	eval-mlogloss:0.33139	train-mlogloss:0.01468
# [620]	eval-mlogloss:0.33175	train-mlogloss:0.01468
# [621]	eval-mlogloss:0.33181	train-mlogloss:0.01468
# [622]	eval-mlogloss:0.33214	train-mlogloss:0.01468
# [623]	eval-mlogloss:0.33219	train-mlogloss:0.01468
# [624]	eval-mlogloss:0.33252	train-mlogloss:0.01467
# [625]	eval-mlogloss:0.33256	train-mlogloss:0.01467
# [626]	eval-mlogloss:0.33289	train-mlogloss:0.01467
# [627]	eval-mlogloss:0.33292	train-mlogloss:0.01467
# [628]	eval-mlogloss:0.33325	train-mlogloss:0.01467
# [629]	eval-mlogloss:0.33328	train-mlogloss:0.01466
# [630]	eval-mlogloss:0.33360	train-mlogloss:0.01466
# [631]	eval-mlogloss:0.33363	train-mlogloss:0.01466
# [632]	eval-mlogloss:0.33326	train-mlogloss:0.01466
# [633]	eval-mlogloss:0.33333	train-mlogloss:0.01465
# [634]	eval-mlogloss:0.33295	train-mlogloss:0.01465
# [635]	eval-mlogloss:0.33302	train-mlogloss:0.01465
# [636]	eval-mlogloss:0.33264	train-mlogloss:0.01465
# [637]	eval-mlogloss:0.33270	train-mlogloss:0.01464
# [638]	eval-mlogloss:0.33306	train-mlogloss:0.01464
# [639]	eval-mlogloss:0.33310	train-mlogloss:0.01464
# [640]	eval-mlogloss:0.33345	train-mlogloss:0.01464
# [641]	eval-mlogloss:0.33349	train-mlogloss:0.01464
# [642]	eval-mlogloss:0.33383	train-mlogloss:0.01463
# [643]	eval-mlogloss:0.33387	train-mlogloss:0.01463
# [644]	eval-mlogloss:0.33419	train-mlogloss:0.01463
# [645]	eval-mlogloss:0.33423	train-mlogloss:0.01463
# [646]	eval-mlogloss:0.33455	train-mlogloss:0.01463
# [647]	eval-mlogloss:0.33459	train-mlogloss:0.01463
# [648]	eval-mlogloss:0.33490	train-mlogloss:0.01462
# [649]	eval-mlogloss:0.33494	train-mlogloss:0.01462
# [650]	eval-mlogloss:0.33456	train-mlogloss:0.01462
# [651]	eval-mlogloss:0.33464	train-mlogloss:0.01462
# [652]	eval-mlogloss:0.33426	train-mlogloss:0.01461
# [653]	eval-mlogloss:0.33459	train-mlogloss:0.01461
# [654]	eval-mlogloss:0.33465	train-mlogloss:0.01461
# [655]	eval-mlogloss:0.33496	train-mlogloss:0.01461
# [656]	eval-mlogloss:0.33501	train-mlogloss:0.01461
# [657]	eval-mlogloss:0.33532	train-mlogloss:0.01461
# [658]	eval-mlogloss:0.33536	train-mlogloss:0.01460
# [659]	eval-mlogloss:0.33567	train-mlogloss:0.01460
# [660]	eval-mlogloss:0.33570	train-mlogloss:0.01460
# [661]	eval-mlogloss:0.33601	train-mlogloss:0.01460
# [662]	eval-mlogloss:0.33604	train-mlogloss:0.01460
# [663]	eval-mlogloss:0.33634	train-mlogloss:0.01460
# [664]	eval-mlogloss:0.33637	train-mlogloss:0.01459
# [665]	eval-mlogloss:0.33602	train-mlogloss:0.01459
# [666]	eval-mlogloss:0.33609	train-mlogloss:0.01459
# [667]	eval-mlogloss:0.33572	train-mlogloss:0.01459
# [668]	eval-mlogloss:0.33604	train-mlogloss:0.01458
# [669]	eval-mlogloss:0.33610	train-mlogloss:0.01458
# [670]	eval-mlogloss:0.33640	train-mlogloss:0.01458
# [671]	eval-mlogloss:0.33644	train-mlogloss:0.01458
# [672]	eval-mlogloss:0.33674	train-mlogloss:0.01458
# [673]	eval-mlogloss:0.33678	train-mlogloss:0.01458
# [674]	eval-mlogloss:0.33707	train-mlogloss:0.01457
# [675]	eval-mlogloss:0.33711	train-mlogloss:0.01457
# [676]	eval-mlogloss:0.33740	train-mlogloss:0.01457
# [677]	eval-mlogloss:0.33744	train-mlogloss:0.01457
# [678]	eval-mlogloss:0.33748	train-mlogloss:0.01457
# [679]	eval-mlogloss:0.33707	train-mlogloss:0.01456
# [680]	eval-mlogloss:0.33674	train-mlogloss:0.01456
# [681]	eval-mlogloss:0.33682	train-mlogloss:0.01456
# [682]	eval-mlogloss:0.33647	train-mlogloss:0.01456
# [683]	eval-mlogloss:0.33653	train-mlogloss:0.01455
# [684]	eval-mlogloss:0.33621	train-mlogloss:0.01455
# [685]	eval-mlogloss:0.33630	train-mlogloss:0.01455
# [686]	eval-mlogloss:0.33596	train-mlogloss:0.01455
# [687]	eval-mlogloss:0.33601	train-mlogloss:0.01455
# [688]	eval-mlogloss:0.33572	train-mlogloss:0.01454
# [689]	eval-mlogloss:0.33580	train-mlogloss:0.01454
# [690]	eval-mlogloss:0.33548	train-mlogloss:0.01454
# [691]	eval-mlogloss:0.33522	train-mlogloss:0.01454
# [692]	eval-mlogloss:0.33530	train-mlogloss:0.01453
# [693]	eval-mlogloss:0.33501	train-mlogloss:0.01453
# [694]	eval-mlogloss:0.33506	train-mlogloss:0.01453
# [695]	eval-mlogloss:0.33480	train-mlogloss:0.01453
# [696]	eval-mlogloss:0.33488	train-mlogloss:0.01453
# [697]	eval-mlogloss:0.33459	train-mlogloss:0.01452
# [698]	eval-mlogloss:0.33463	train-mlogloss:0.01452
# [699]	eval-mlogloss:0.33437	train-mlogloss:0.01452
# [700]	eval-mlogloss:0.33442	train-mlogloss:0.01452
# [701]	eval-mlogloss:0.33448	train-mlogloss:0.01452
# [702]	eval-mlogloss:0.33418	train-mlogloss:0.01452
# [703]	eval-mlogloss:0.33394	train-mlogloss:0.01452
# [704]	eval-mlogloss:0.33395	train-mlogloss:0.01452
# [705]	eval-mlogloss:0.33401	train-mlogloss:0.01451
# [706]	eval-mlogloss:0.33373	train-mlogloss:0.01451
# [707]	eval-mlogloss:0.33377	train-mlogloss:0.01451
# [708]	eval-mlogloss:0.33352	train-mlogloss:0.01451
# [709]	eval-mlogloss:0.33359	train-mlogloss:0.01451
# [710]	eval-mlogloss:0.33332	train-mlogloss:0.01450
# [711]	eval-mlogloss:0.33310	train-mlogloss:0.01450
# [712]	eval-mlogloss:0.33318	train-mlogloss:0.01450
# [713]	eval-mlogloss:0.33293	train-mlogloss:0.01450
# [714]	eval-mlogloss:0.33297	train-mlogloss:0.01450
# [715]	eval-mlogloss:0.33275	train-mlogloss:0.01450
# [716]	eval-mlogloss:0.33280	train-mlogloss:0.01450
# [717]	eval-mlogloss:0.33279	train-mlogloss:0.01450
# [718]	eval-mlogloss:0.33258	train-mlogloss:0.01450
# [719]	eval-mlogloss:0.33262	train-mlogloss:0.01450
# [720]	eval-mlogloss:0.33261	train-mlogloss:0.01449
# [721]	eval-mlogloss:0.33266	train-mlogloss:0.01449
# [722]	eval-mlogloss:0.33240	train-mlogloss:0.01449
# [723]	eval-mlogloss:0.33219	train-mlogloss:0.01449
# [724]	eval-mlogloss:0.33223	train-mlogloss:0.01449
# [725]	eval-mlogloss:0.33203	train-mlogloss:0.01449
# [726]	eval-mlogloss:0.33207	train-mlogloss:0.01449
# [727]	eval-mlogloss:0.33206	train-mlogloss:0.01449
# [728]	eval-mlogloss:0.33208	train-mlogloss:0.01449
# [729]	eval-mlogloss:0.33189	train-mlogloss:0.01449
# [730]	eval-mlogloss:0.33189	train-mlogloss:0.01449
# [731]	eval-mlogloss:0.33191	train-mlogloss:0.01449
# [732]	eval-mlogloss:0.33173	train-mlogloss:0.01449
# [733]	eval-mlogloss:0.33176	train-mlogloss:0.01448
# [734]	eval-mlogloss:0.33175	train-mlogloss:0.01448
# [735]	eval-mlogloss:0.33177	train-mlogloss:0.01448
# [736]	eval-mlogloss:0.33160	train-mlogloss:0.01448
# [737]	eval-mlogloss:0.33159	train-mlogloss:0.01448
# [738]	eval-mlogloss:0.33161	train-mlogloss:0.01448
# [739]	eval-mlogloss:0.33146	train-mlogloss:0.01448
# [740]	eval-mlogloss:0.33148	train-mlogloss:0.01448
# [741]	eval-mlogloss:0.33148	train-mlogloss:0.01448
# [742]	eval-mlogloss:0.33149	train-mlogloss:0.01448
# [743]	eval-mlogloss:0.33134	train-mlogloss:0.01448
# [744]	eval-mlogloss:0.33134	train-mlogloss:0.01448
# [745]	eval-mlogloss:0.33135	train-mlogloss:0.01448
# [746]	eval-mlogloss:0.33122	train-mlogloss:0.01448
# [747]	eval-mlogloss:0.33124	train-mlogloss:0.01448
# [748]	eval-mlogloss:0.33123	train-mlogloss:0.01448
# [749]	eval-mlogloss:0.33124	train-mlogloss:0.01448
# [750]	eval-mlogloss:0.33111	train-mlogloss:0.01448
# [751]	eval-mlogloss:0.33111	train-mlogloss:0.01448
# [752]	eval-mlogloss:0.33161	train-mlogloss:0.01448
# [753]	eval-mlogloss:0.33164	train-mlogloss:0.01447
# [754]	eval-mlogloss:0.33166	train-mlogloss:0.01447
# [755]	eval-mlogloss:0.33167	train-mlogloss:0.01447
# [756]	eval-mlogloss:0.33215	train-mlogloss:0.01447
# [757]	eval-mlogloss:0.33217	train-mlogloss:0.01447
# [758]	eval-mlogloss:0.33219	train-mlogloss:0.01447
# [759]	eval-mlogloss:0.33220	train-mlogloss:0.01447
# [760]	eval-mlogloss:0.33220	train-mlogloss:0.01447
# [761]	eval-mlogloss:0.33268	train-mlogloss:0.01446
# [762]	eval-mlogloss:0.33270	train-mlogloss:0.01446
# [763]	eval-mlogloss:0.33271	train-mlogloss:0.01446
# [764]	eval-mlogloss:0.33272	train-mlogloss:0.01446
# [765]	eval-mlogloss:0.33272	train-mlogloss:0.01446
# [766]	eval-mlogloss:0.33320	train-mlogloss:0.01446
# [767]	eval-mlogloss:0.33322	train-mlogloss:0.01446
# [768]	eval-mlogloss:0.33323	train-mlogloss:0.01446
# [769]	eval-mlogloss:0.33324	train-mlogloss:0.01446
# [770]	eval-mlogloss:0.33311	train-mlogloss:0.01446
# [771]	eval-mlogloss:0.33312	train-mlogloss:0.01446
# [772]	eval-mlogloss:0.33301	train-mlogloss:0.01446
# [773]	eval-mlogloss:0.33350	train-mlogloss:0.01445
# [774]	eval-mlogloss:0.33353	train-mlogloss:0.01445
# [775]	eval-mlogloss:0.33355	train-mlogloss:0.01445
# [776]	eval-mlogloss:0.33356	train-mlogloss:0.01445
# [777]	eval-mlogloss:0.33357	train-mlogloss:0.01445
# [778]	eval-mlogloss:0.33404	train-mlogloss:0.01445
# [779]	eval-mlogloss:0.33407	train-mlogloss:0.01445
# [780]	eval-mlogloss:0.33408	train-mlogloss:0.01445
# [781]	eval-mlogloss:0.33409	train-mlogloss:0.01445
# [782]	eval-mlogloss:0.33409	train-mlogloss:0.01445
# [783]	eval-mlogloss:0.33456	train-mlogloss:0.01444
# [784]	eval-mlogloss:0.33458	train-mlogloss:0.01444
# [785]	eval-mlogloss:0.33459	train-mlogloss:0.01444
# [786]	eval-mlogloss:0.33460	train-mlogloss:0.01444
# [787]	eval-mlogloss:0.33460	train-mlogloss:0.01444
# [788]	eval-mlogloss:0.33507	train-mlogloss:0.01444
# [789]	eval-mlogloss:0.33509	train-mlogloss:0.01444
# [790]	eval-mlogloss:0.33510	train-mlogloss:0.01444
# [791]	eval-mlogloss:0.33511	train-mlogloss:0.01444
# [792]	eval-mlogloss:0.33511	train-mlogloss:0.01444
# [793]	eval-mlogloss:0.33500	train-mlogloss:0.01444
# [794]	eval-mlogloss:0.33500	train-mlogloss:0.01444
# [795]	eval-mlogloss:0.33548	train-mlogloss:0.01443
# [796]	eval-mlogloss:0.33550	train-mlogloss:0.01443
# [797]	eval-mlogloss:0.33552	train-mlogloss:0.01443
# [798]	eval-mlogloss:0.33552	train-mlogloss:0.01443
# [799]	eval-mlogloss:0.33553	train-mlogloss:0.01443
# [800]	eval-mlogloss:0.33543	train-mlogloss:0.01443
# [801]	eval-mlogloss:0.33589	train-mlogloss:0.01443
# [802]	eval-mlogloss:0.33592	train-mlogloss:0.01443
# [803]	eval-mlogloss:0.33594	train-mlogloss:0.01443
# [804]	eval-mlogloss:0.33595	train-mlogloss:0.01443
# [805]	eval-mlogloss:0.33596	train-mlogloss:0.01443
# [806]	eval-mlogloss:0.33641	train-mlogloss:0.01443
# [807]	eval-mlogloss:0.33643	train-mlogloss:0.01443
# [808]	eval-mlogloss:0.33644	train-mlogloss:0.01443
# [809]	eval-mlogloss:0.33645	train-mlogloss:0.01443
# [810]	eval-mlogloss:0.33646	train-mlogloss:0.01443
# [811]	eval-mlogloss:0.33636	train-mlogloss:0.01443
# [812]	eval-mlogloss:0.33637	train-mlogloss:0.01443
# [813]	eval-mlogloss:0.33683	train-mlogloss:0.01442
# [814]	eval-mlogloss:0.33685	train-mlogloss:0.01442
# [815]	eval-mlogloss:0.33686	train-mlogloss:0.01442
# [816]	eval-mlogloss:0.33687	train-mlogloss:0.01442
# [817]	eval-mlogloss:0.33688	train-mlogloss:0.01442
# [818]	eval-mlogloss:0.33679	train-mlogloss:0.01442
# [819]	eval-mlogloss:0.33724	train-mlogloss:0.01442
# [820]	eval-mlogloss:0.33727	train-mlogloss:0.01442
# [821]	eval-mlogloss:0.33729	train-mlogloss:0.01442
# [822]	eval-mlogloss:0.33730	train-mlogloss:0.01442
# [823]	eval-mlogloss:0.33730	train-mlogloss:0.01442
# [824]	eval-mlogloss:0.33731	train-mlogloss:0.01442
# [825]	eval-mlogloss:0.33775	train-mlogloss:0.01441
# [826]	eval-mlogloss:0.33777	train-mlogloss:0.01441
# [827]	eval-mlogloss:0.33779	train-mlogloss:0.01441
# [828]	eval-mlogloss:0.33779	train-mlogloss:0.01441
# [829]	eval-mlogloss:0.33780	train-mlogloss:0.01441
# [830]	eval-mlogloss:0.33771	train-mlogloss:0.01441
# [831]	eval-mlogloss:0.33772	train-mlogloss:0.01441
# [832]	eval-mlogloss:0.33817	train-mlogloss:0.01441
# [833]	eval-mlogloss:0.33819	train-mlogloss:0.01441
# [834]	eval-mlogloss:0.33821	train-mlogloss:0.01441
# [835]	eval-mlogloss:0.33821	train-mlogloss:0.01441
# [836]	eval-mlogloss:0.33822	train-mlogloss:0.01441
# [837]	eval-mlogloss:0.33822	train-mlogloss:0.01441
# [838]	eval-mlogloss:0.33867	train-mlogloss:0.01440
# [839]	eval-mlogloss:0.33869	train-mlogloss:0.01440
# [840]	eval-mlogloss:0.33870	train-mlogloss:0.01440
# [841]	eval-mlogloss:0.33871	train-mlogloss:0.01440
# [842]	eval-mlogloss:0.33871	train-mlogloss:0.01440
# [843]	eval-mlogloss:0.33863	train-mlogloss:0.01440
# [844]	eval-mlogloss:0.33864	train-mlogloss:0.01440
# [845]	eval-mlogloss:0.33856	train-mlogloss:0.01440
# [846]	eval-mlogloss:0.33901	train-mlogloss:0.01440
# [847]	eval-mlogloss:0.33903	train-mlogloss:0.01440
# [848]	eval-mlogloss:0.33905	train-mlogloss:0.01440
# [849]	eval-mlogloss:0.33906	train-mlogloss:0.01440
# [850]	eval-mlogloss:0.33907	train-mlogloss:0.01440
# [851]	eval-mlogloss:0.33907	train-mlogloss:0.01440
# [852]	eval-mlogloss:0.33951	train-mlogloss:0.01440
# [853]	eval-mlogloss:0.33953	train-mlogloss:0.01440
# [854]	eval-mlogloss:0.33954	train-mlogloss:0.01440
# [855]	eval-mlogloss:0.33955	train-mlogloss:0.01440
# [856]	eval-mlogloss:0.33955	train-mlogloss:0.01440
# [857]	eval-mlogloss:0.33956	train-mlogloss:0.01440
# [858]	eval-mlogloss:0.33948	train-mlogloss:0.01440
# [859]	eval-mlogloss:0.33992	train-mlogloss:0.01439
# [860]	eval-mlogloss:0.33994	train-mlogloss:0.01439
# [861]	eval-mlogloss:0.33996	train-mlogloss:0.01439
# [862]	eval-mlogloss:0.33997	train-mlogloss:0.01439
# [863]	eval-mlogloss:0.33997	train-mlogloss:0.01439
# [864]	eval-mlogloss:0.33997	train-mlogloss:0.01439
# [865]	eval-mlogloss:0.34040	train-mlogloss:0.01439
# [866]	eval-mlogloss:0.34042	train-mlogloss:0.01439
# [867]	eval-mlogloss:0.34043	train-mlogloss:0.01439
# [868]	eval-mlogloss:0.34044	train-mlogloss:0.01439
# [869]	eval-mlogloss:0.34045	train-mlogloss:0.01439
# [870]	eval-mlogloss:0.34045	train-mlogloss:0.01439
# [871]	eval-mlogloss:0.34037	train-mlogloss:0.01439
# [872]	eval-mlogloss:0.34038	train-mlogloss:0.01439
# [873]	eval-mlogloss:0.34081	train-mlogloss:0.01439
# [874]	eval-mlogloss:0.34083	train-mlogloss:0.01439
# [875]	eval-mlogloss:0.34085	train-mlogloss:0.01439
# [876]	eval-mlogloss:0.34085	train-mlogloss:0.01439
# [877]	eval-mlogloss:0.34086	train-mlogloss:0.01439
# [878]	eval-mlogloss:0.34086	train-mlogloss:0.01439
# [879]	eval-mlogloss:0.34080	train-mlogloss:0.01439
# [880]	eval-mlogloss:0.34122	train-mlogloss:0.01438
# [881]	eval-mlogloss:0.34124	train-mlogloss:0.01438
# [882]	eval-mlogloss:0.34126	train-mlogloss:0.01438
# [883]	eval-mlogloss:0.34127	train-mlogloss:0.01438
# [884]	eval-mlogloss:0.34128	train-mlogloss:0.01438
# [885]	eval-mlogloss:0.34128	train-mlogloss:0.01438
# [886]	eval-mlogloss:0.34169	train-mlogloss:0.01438
# [887]	eval-mlogloss:0.34171	train-mlogloss:0.01438
# [888]	eval-mlogloss:0.34173	train-mlogloss:0.01438
# [889]	eval-mlogloss:0.34173	train-mlogloss:0.01438
# [890]	eval-mlogloss:0.34174	train-mlogloss:0.01438
# [891]	eval-mlogloss:0.34174	train-mlogloss:0.01438
# [892]	eval-mlogloss:0.34167	train-mlogloss:0.01438
# [893]	eval-mlogloss:0.34168	train-mlogloss:0.01438
# [894]	eval-mlogloss:0.34210	train-mlogloss:0.01438
# [895]	eval-mlogloss:0.34212	train-mlogloss:0.01438
# [896]	eval-mlogloss:0.34213	train-mlogloss:0.01437
# [897]	eval-mlogloss:0.34214	train-mlogloss:0.01437
# [898]	eval-mlogloss:0.34215	train-mlogloss:0.01437
# [899]	eval-mlogloss:0.34215	train-mlogloss:0.01437
# [900]	eval-mlogloss:0.34209	train-mlogloss:0.01437
# [901]	eval-mlogloss:0.34209	train-mlogloss:0.01437
# [902]	eval-mlogloss:0.34251	train-mlogloss:0.01437
# [903]	eval-mlogloss:0.34253	train-mlogloss:0.01437
# [904]	eval-mlogloss:0.34255	train-mlogloss:0.01437
# [905]	eval-mlogloss:0.34255	train-mlogloss:0.01437
# [906]	eval-mlogloss:0.34256	train-mlogloss:0.01437
# [907]	eval-mlogloss:0.34256	train-mlogloss:0.01437
# [908]	eval-mlogloss:0.34250	train-mlogloss:0.01437
# [909]	eval-mlogloss:0.34251	train-mlogloss:0.01437
# [910]	eval-mlogloss:0.34292	train-mlogloss:0.01437
# [911]	eval-mlogloss:0.34294	train-mlogloss:0.01437
# [912]	eval-mlogloss:0.34296	train-mlogloss:0.01437
# [913]	eval-mlogloss:0.34296	train-mlogloss:0.01437
# [914]	eval-mlogloss:0.34297	train-mlogloss:0.01437
# [915]	eval-mlogloss:0.34297	train-mlogloss:0.01437
# [916]	eval-mlogloss:0.34297	train-mlogloss:0.01437
# [917]	eval-mlogloss:0.34338	train-mlogloss:0.01437
# [918]	eval-mlogloss:0.34340	train-mlogloss:0.01436
# [919]	eval-mlogloss:0.34341	train-mlogloss:0.01436
# [920]	eval-mlogloss:0.34342	train-mlogloss:0.01436
# [921]	eval-mlogloss:0.34342	train-mlogloss:0.01436
# [922]	eval-mlogloss:0.34343	train-mlogloss:0.01436
# [923]	eval-mlogloss:0.34337	train-mlogloss:0.01436
# [924]	eval-mlogloss:0.34337	train-mlogloss:0.01436
# [925]	eval-mlogloss:0.34332	train-mlogloss:0.01436
# [926]	eval-mlogloss:0.34333	train-mlogloss:0.01436
# [927]	eval-mlogloss:0.34374	train-mlogloss:0.01436
# [928]	eval-mlogloss:0.34376	train-mlogloss:0.01436
# [929]	eval-mlogloss:0.34378	train-mlogloss:0.01436
# [930]	eval-mlogloss:0.34378	train-mlogloss:0.01436
# [931]	eval-mlogloss:0.34379	train-mlogloss:0.01436
# [932]	eval-mlogloss:0.34379	train-mlogloss:0.01436
# [933]	eval-mlogloss:0.34379	train-mlogloss:0.01436
# [934]	eval-mlogloss:0.34420	train-mlogloss:0.01436
# [935]	eval-mlogloss:0.34422	train-mlogloss:0.01436
# [936]	eval-mlogloss:0.34423	train-mlogloss:0.01436
# [937]	eval-mlogloss:0.34423	train-mlogloss:0.01436
# [938]	eval-mlogloss:0.34424	train-mlogloss:0.01436
# [939]	eval-mlogloss:0.34424	train-mlogloss:0.01436
# [940]	eval-mlogloss:0.34424	train-mlogloss:0.01436
# [941]	eval-mlogloss:0.34419	train-mlogloss:0.01436
# [942]	eval-mlogloss:0.34459	train-mlogloss:0.01436
# [943]	eval-mlogloss:0.34461	train-mlogloss:0.01436
# [944]	eval-mlogloss:0.34462	train-mlogloss:0.01436
# [945]	eval-mlogloss:0.34463	train-mlogloss:0.01436
# [946]	eval-mlogloss:0.34464	train-mlogloss:0.01436
# [947]	eval-mlogloss:0.34464	train-mlogloss:0.01436
# [948]	eval-mlogloss:0.34464	train-mlogloss:0.01436
# [949]	eval-mlogloss:0.34459	train-mlogloss:0.01436
# [950]	eval-mlogloss:0.34460	train-mlogloss:0.01436
# [951]	eval-mlogloss:0.34500	train-mlogloss:0.01435
# [952]	eval-mlogloss:0.34501	train-mlogloss:0.01435
# [953]	eval-mlogloss:0.34503	train-mlogloss:0.01435
# [954]	eval-mlogloss:0.34504	train-mlogloss:0.01435
# [955]	eval-mlogloss:0.34504	train-mlogloss:0.01435
# [956]	eval-mlogloss:0.34504	train-mlogloss:0.01435
# [957]	eval-mlogloss:0.34504	train-mlogloss:0.01435
# [958]	eval-mlogloss:0.34500	train-mlogloss:0.01435
# [959]	eval-mlogloss:0.34539	train-mlogloss:0.01435
# [960]	eval-mlogloss:0.34541	train-mlogloss:0.01435
# [961]	eval-mlogloss:0.34542	train-mlogloss:0.01435
# [962]	eval-mlogloss:0.34543	train-mlogloss:0.01435
# [963]	eval-mlogloss:0.34544	train-mlogloss:0.01435
# [964]	eval-mlogloss:0.34544	train-mlogloss:0.01435
# [965]	eval-mlogloss:0.34544	train-mlogloss:0.01435
# [966]	eval-mlogloss:0.34540	train-mlogloss:0.01435
# [967]	eval-mlogloss:0.34540	train-mlogloss:0.01435
# [968]	eval-mlogloss:0.34579	train-mlogloss:0.01435
# [969]	eval-mlogloss:0.34581	train-mlogloss:0.01435
# [970]	eval-mlogloss:0.34582	train-mlogloss:0.01435
# [971]	eval-mlogloss:0.34583	train-mlogloss:0.01435
# [972]	eval-mlogloss:0.34584	train-mlogloss:0.01435
# [973]	eval-mlogloss:0.34584	train-mlogloss:0.01435
# [974]	eval-mlogloss:0.34584	train-mlogloss:0.01435
# [975]	eval-mlogloss:0.34580	train-mlogloss:0.01435
# [976]	eval-mlogloss:0.34580	train-mlogloss:0.01435
# [977]	eval-mlogloss:0.34619	train-mlogloss:0.01434
# [978]	eval-mlogloss:0.34621	train-mlogloss:0.01434
# [979]	eval-mlogloss:0.34622	train-mlogloss:0.01434
# [980]	eval-mlogloss:0.34623	train-mlogloss:0.01434
# [981]	eval-mlogloss:0.34623	train-mlogloss:0.01434
# [982]	eval-mlogloss:0.34624	train-mlogloss:0.01434
# [983]	eval-mlogloss:0.34624	train-mlogloss:0.01434
# [984]	eval-mlogloss:0.34624	train-mlogloss:0.01434
# [985]	eval-mlogloss:0.34620	train-mlogloss:0.01434
# [986]	eval-mlogloss:0.34620	train-mlogloss:0.01434
# [987]	eval-mlogloss:0.34617	train-mlogloss:0.01434
# [988]	eval-mlogloss:0.34617	train-mlogloss:0.01434
# [989]	eval-mlogloss:0.34656	train-mlogloss:0.01434
# [990]	eval-mlogloss:0.34658	train-mlogloss:0.01434
# [991]	eval-mlogloss:0.34660	train-mlogloss:0.01434
# [992]	eval-mlogloss:0.34661	train-mlogloss:0.01434
# [993]	eval-mlogloss:0.34661	train-mlogloss:0.01434
# [994]	eval-mlogloss:0.34662	train-mlogloss:0.01434
# [995]	eval-mlogloss:0.34661	train-mlogloss:0.01434
# [996]	eval-mlogloss:0.34662	train-mlogloss:0.01434
# [997]	eval-mlogloss:0.34662	train-mlogloss:0.01434
# [998]	eval-mlogloss:0.34658	train-mlogloss:0.01434
# [999]	eval-mlogloss:0.34659	train-mlogloss:0.01434
# [1000]	eval-mlogloss:0.34656	train-mlogloss:0.01434
# [1001]	eval-mlogloss:0.34656	train-mlogloss:0.01434
# [1002]	eval-mlogloss:0.34653	train-mlogloss:0.01434
# [1003]	eval-mlogloss:0.34693	train-mlogloss:0.01434
# [1004]	eval-mlogloss:0.34695	train-mlogloss:0.01434
# [1005]	eval-mlogloss:0.34696	train-mlogloss:0.01434
# [1006]	eval-mlogloss:0.34697	train-mlogloss:0.01434
# [1007]	eval-mlogloss:0.34698	train-mlogloss:0.01434
# [1008]	eval-mlogloss:0.34698	train-mlogloss:0.01434
# [1009]	eval-mlogloss:0.34698	train-mlogloss:0.01434
# [1010]	eval-mlogloss:0.34698	train-mlogloss:0.01434
# [1011]	eval-mlogloss:0.34698	train-mlogloss:0.01434
# [1012]	eval-mlogloss:0.34698	train-mlogloss:0.01434
# [1013]	eval-mlogloss:0.34695	train-mlogloss:0.01434
# [1014]	eval-mlogloss:0.34696	train-mlogloss:0.01434
# [1015]	eval-mlogloss:0.34693	train-mlogloss:0.01434
# [1016]	eval-mlogloss:0.34694	train-mlogloss:0.01434
# [1017]	eval-mlogloss:0.34733	train-mlogloss:0.01434
# [1018]	eval-mlogloss:0.34735	train-mlogloss:0.01433
# [1019]	eval-mlogloss:0.34736	train-mlogloss:0.01433
# [1020]	eval-mlogloss:0.34737	train-mlogloss:0.01433
# [1021]	eval-mlogloss:0.34738	train-mlogloss:0.01433
# [1022]	eval-mlogloss:0.34738	train-mlogloss:0.01433
# [1023]	eval-mlogloss:0.34738	train-mlogloss:0.01433
# [1024]	eval-mlogloss:0.34738	train-mlogloss:0.01433
# [1025]	eval-mlogloss:0.34738	train-mlogloss:0.01433
# [1026]	eval-mlogloss:0.34735	train-mlogloss:0.01433
# [1027]	eval-mlogloss:0.34736	train-mlogloss:0.01433
# [1028]	eval-mlogloss:0.34733	train-mlogloss:0.01433
# [1029]	eval-mlogloss:0.34733	train-mlogloss:0.01433
# [1030]	eval-mlogloss:0.34734	train-mlogloss:0.01433
# [1031]	eval-mlogloss:0.34731	train-mlogloss:0.01433
# [1032]	eval-mlogloss:0.34732	train-mlogloss:0.01433
# [1033]	eval-mlogloss:0.34730	train-mlogloss:0.01433
# [1034]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1035]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1036]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1037]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1038]	eval-mlogloss:0.34774	train-mlogloss:0.01433
# [1039]	eval-mlogloss:0.34774	train-mlogloss:0.01433
# [1040]	eval-mlogloss:0.34774	train-mlogloss:0.01433
# [1041]	eval-mlogloss:0.34775	train-mlogloss:0.01433
# [1042]	eval-mlogloss:0.34774	train-mlogloss:0.01433
# [1043]	eval-mlogloss:0.34775	train-mlogloss:0.01433
# [1044]	eval-mlogloss:0.34775	train-mlogloss:0.01433
# [1045]	eval-mlogloss:0.34774	train-mlogloss:0.01433
# [1046]	eval-mlogloss:0.34774	train-mlogloss:0.01433
# [1047]	eval-mlogloss:0.34774	train-mlogloss:0.01433
# [1048]	eval-mlogloss:0.34774	train-mlogloss:0.01433
# [1049]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1050]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1051]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1052]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1053]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1054]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1055]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1056]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1057]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1058]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1059]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1060]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1061]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1062]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1063]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1064]	eval-mlogloss:0.34772	train-mlogloss:0.01433
# [1065]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1066]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1067]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1068]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1069]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1070]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1071]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1072]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1073]	eval-mlogloss:0.34773	train-mlogloss:0.01433
# [1074]	eval-mlogloss:0.34770	train-mlogloss:0.01433
# [1075]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1076]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1077]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1078]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1079]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1080]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1081]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1082]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1083]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1084]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1085]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1086]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1087]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1088]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1089]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1090]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1091]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1092]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1093]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1094]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1095]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1096]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1097]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1098]	eval-mlogloss:0.34771	train-mlogloss:0.01433
# [1099]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1100]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1101]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1102]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1103]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1104]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1105]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1106]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1107]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1108]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1109]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1110]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1111]	eval-mlogloss:0.34770	train-mlogloss:0.01433
# [1112]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1113]	eval-mlogloss:0.34770	train-mlogloss:0.01433
# [1114]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1115]	eval-mlogloss:0.34770	train-mlogloss:0.01433
# [1116]	eval-mlogloss:0.34769	train-mlogloss:0.01433
# [1117]	eval-mlogloss:0.34770	train-mlogloss:0.01433
# [1118]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1119]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1120]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1121]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1122]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1123]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1124]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1125]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1126]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1127]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1128]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1129]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1130]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1131]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1132]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1133]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1134]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1135]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1136]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1137]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1138]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1139]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1140]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1141]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1142]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1143]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1144]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1145]	eval-mlogloss:0.34768	train-mlogloss:0.01433
# [1146]	eval-mlogloss:0.34768	train-mlogloss:0.01433

# %% [markdown]
# ## [2-5] Confirming the result of the validation

# %%
#print('Best Score:{0:.4f}, Iteration:{1:d}, Ntree_limit:{2:d}'.format(bst.best_score,bst.best_iteration,bst.best_ntree_limit))
#print('Best Score:{0:.4f}, Iteratin:{1:d}, Ntree_Limit:{2:d}'.format(
#     bst.best_score, bst.best_iteration, bst.best_ntree_limit))
# Best Score:0.0186, Iteratin:1153, Ntree_Limit:1154
bst.attributes()
# Out:
# {'best_iteration': '1142', 'best_score': '0.01433143718024136'}

# %% [markdown]
# ## [2-6] Prediction
#
# Performing predictions with the model that had the best results out of the validation results.

# %%
dtest = xgb.DMatrix(test_x)
pred = ypred = bst.predict(dtest)
#ntree_limit = bst.best_ntree_limit

# %%
print(ypred)
# Out:
# [1. 2. 1. 0. 0. 1. 2. 0. 1. 1. 2. 1. 1. 1. 1. 1. 0. 0. 0. 1. 1. 1. 2. 0.
#  2. 1. 2. 2. 0. 0.]

# %%
print(dtest)
# Out:
# <xgboost.core.DMatrix object at 0x000002069E3AB8D0>

# %% [markdown]
# ## Finally
#
# For people with experience in machine learning, using the pandas DataFrame and Series might have seemed easy.
#
# This example was about multiple class classification, but can just as well be used for binary classification and regression. This approach can be helpful in many different situations.

# %%
### End of J->E, switch E->J

# %% [markdown]
# # Shap
#
# Shap is a python package that allows you to analyze and debug you models.
# Shap values are used to explain individual model predictions, informing about how much a feature has influenced the prediciton.
#
# while feature importance informs about how a feature affects the predictions in general, shap values give insight into how features influences **individual predicitons**.
#
# Esentially gives you an understanding of how machine learning models work.

# %% [markdown]
# ## SHAP
#
# SHAPは機械学習モデルの解析とデバッグを可能にするpythonパッケージです。
# そのパッケージはモデルの予測のシャープレイ値を算出し、特徴量ごとが予測の影響が分かるようになります。
#
#
# while feature importance informs about how a feature affects the predictions in general, shap values give insight into how features influences **individual predicitons**.
#
# Esentially gives you an understanding of how machine learning models work.

# %% [markdown]
# ## Shapley Values
#
# Shapely values are a concept from cooperative game theroy to provide a way to fairly distribute the payoff of a cooperative game among players based on their contributions.
# They are a method for assigning a fair share of the total payoff to each player in as cooperative game. They are based on the idea of marginal contributions: the additional value each player brings when joining a coalition.
#
# The calculation of Shapley values involve considering all possible permutations of players joining the coalition and computing the marginal contribution of each player to each possible permutation. The Shapley value of a player is then the average of their marginal controbition over all possible permutations.
#
# In the context of machine learning,
#
# [source](https://www.youtube.com/watch?v=UJeu29wq7d0&list=PLqDyyww9y-1SJgMw92x90qPYpHgahDLIK&index=3)

# %%
## Shap

# %% [markdown]
# ## Using Shap
#
# Since shap is a package it needs to be imported alongside a few other packages that make working with it a bit more easier.
# This includes the matplotlib, pandas, numpy and seaborn package.
# Since pandas is already in this scrip, it will not be imported.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import shap

# %% [markdown]
# Shap also needs to be initilaized  in order to be able to be used.

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# The shap.TreeExplainer function desinged to explain prediction made by tree based models, such as the gradient tree bosting algorythm in this case.
# It takes in a model a model as an argument and then provides the shapley values for each feature in each prediction made in the provided data set.

# %%
explainer = shap.TreeExplainer(bst)
shap_values = explainer(test_x)

# %% [markdown]
# For continuous or binary predictions, the explainer returns a list of arrays that contain a shapley value for each feature in each input data, in other words, a shapley value for each feature value.
# However in this case, since we have a multi class classification, the shapley values for each input are calculated for each class.
# The sum of the values show the probaility of the input being of that specific class and the model selects the one with the hightest probabiliy as the output of the model.

# %%
print(np.shape(shap_values))
# Out:
# (30, 4, 3)

# %% [markdown]
# Here we show the waterfalldiagramms for all three classes of for the second row of the data.

# %%
shap.plots.waterfall(shap_values[1,:,0])
shap.plots.waterfall(shap_values[1,:,1])
shap.plots.waterfall(shap_values[1,:,2])

# %% [markdown]
# In this case, this data was predicted to be of the 2nd type of class. From the charts below we can see that this matches both the predicted, and the manual classifications match.

# %% [markdown]
# Calculating the absolute mean of the shap values.

# %%
mean_0 = np.mean(np.abs(shap_values.values[:,:,0]),axis =0)
mean_1 = np.mean(np.abs(shap_values.values[:,:,1]),axis =0)
mean_2 = np.mean(np.abs(shap_values.values[:,:,2]),axis =0)

df= pd.DataFrame({"Class0": mean_0,"Class1": mean_1,"Class2": mean_2})

fig, ax  = plt.subplots(1,1, figsize =(20,10))
df.plot.bar(ax= ax)

ax.set_ylabel("Mean SHAP", size = 30)
ax.set_xticklabels(iris.feature_names, rotation = 45, size = 20)
ax.legend(fontsize = 30)

# %% [markdown]
# shap values for only the predicted class

# %%
Tnew_shap_values =[]
for i, pre in enumerate(pred) :
    #print(pre)
    #print(i)
    #print(shap_values.values[i][:,int(pre)])
    Tnew_shap_values.append(shap_values.values[i][:,int(pre)])

#new_shap_values = shap_values
#new_shap_value.values = np.array(Tnew_shap_values)
#shap_values.values = np.array(new_shap_values)

# %%
import copy
new_shap_values= copy.deepcopy(shap_values)

# %%
new_shap_values.values = np.array(Tnew_shap_values)

# %%
shap.plots.bar(new_shap_values)

# %%
shap.plots.beeswarm(new_shap_values)

# %%
shap_feature_names = []
for f in iris.feature_names :
    shap_feature_names.append("SHARP for "+ f)

combined_column_names =iris.feature_names + shap_feature_names
print(combined_column_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'SHARP for sepal length (cm)', 'SHARP for sepal width (cm)', 'SHARP for petal length (cm)', 'SHARP for petal width (cm)']

# %%
#predicted_shap_df = pd.DataFrame(new_shap_values.values, columns=iris.feature_names)
predicted_shap_df = pd.DataFrame(new_shap_values.values, columns=shap_feature_names)
commbined_np_list = np.concatenate((test_x,predicted_shap_df ), axis=1)
combined_df = pd.DataFrame(commbined_np_list, columns=combined_column_names)

# %%
combined_df.to_csv('predicted_shap_values_combined.csv', index=False)

# %%
print(iris.feature_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
full_result_data = []
for i in range(len(shap_values)) :
    data_1 = shap_values.values[i][:,0]
    data_2 = shap_values.values[i][:,1]
    data_3 = shap_values.values[i][:,2]
    args = (data_1, data_2, data_3)
    return_data = np.concatenate(args)
    full_result_data.append(return_data)

# %%
full_shap_feature_names = []
for i in range(3):
    for f in iris.feature_names :
        full_shap_feature_names.append("SHARP for "+ f + " Class" + str(i+1))

full_column_names =iris.feature_names + full_shap_feature_names
print(full_column_names)
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'SHARP for sepal length (cm) Class1', 'SHARP for sepal width (cm) Class1', 'SHARP for petal length (cm) Class1', 'SHARP for petal width (cm) Class1', 'SHARP for sepal length (cm) Class2', 'SHARP for sepal width (cm) Class2', 'SHARP for petal length (cm) Class2', 'SHARP for petal width (cm) Class2', 'SHARP for sepal length (cm) Class3', 'SHARP for sepal width (cm) Class3', 'SHARP for petal length (cm) Class3', 'SHARP for petal width (cm) Class3']

# %%
full_np_list = np.concatenate((test_x,full_result_data ), axis=1)
full_df = pd.DataFrame(full_np_list, columns=full_column_names)

# %%
full_df.to_csv('full_shap_values.csv', index=False)

# %% [markdown]
# # Cross Validation
#
# Cross validation describes a process artificially expanding the training set by rotating training and testing sets.
# When working with a limited amount of data, often times it can be very important to include all of the sampled data in the training set. However, doing this would not allow you to leave any data for testing and if testing was performed on trained data sets, it would taint the testing set. But small data sets also have the disadvantage of having outliers influence the result significantly. This is where cross valiadation comes into play.
#
# Here the sets are split into even blocks, usually 5 or 10, and one of those sets is designated the testing set.
# Then a model is trained using using the training data, and tested using the testing data, as well as assiged an accuaracy.
# Following this, another model is trained by using a different data block as the testing data. The process is repeated until all of the blocks have served as the testing data once. Then the performance of the models will be averaged and provide an output as the average performance.
# Since the data can be split into k number of parts, it is also called k-fold cross valiadation.
#
# ![image.png](attachment:85ac6d38-0ca8-492f-9572-347640bd4139.png)

# %% [markdown]
# Things required:
#
# sk_learn KFold

# %%
print(iris_data)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
from sklearn.model_selection import KFold

fold_test_list_x = []
fold_test_list_y = []
fold_valid_list_x = []
fold_valid_list_y = []
kf = KFold(n_splits = 5)

for train, valid in kf.split(iris_data):
    x_tr = iris_data.loc[train]
    x_val = iris_data.loc[valid]

    y_tr = iris_target.loc[train]
    y_val = iris_target.loc[valid]
    
    fold_test_list_x.append(x_tr)
    fold_test_list_y.append(y_tr)
    
    fold_valid_list_x.append(x_val)
    fold_valid_list_y.append(y_val)

# %%
def train_model_custom(train_x, train_y) :
    dtrain = xgb.DMatrix(train_x, label=train_y)
    param = {'max_depth' : 2, 'eta' : 1, 'objective': 'multi:softmax', 'num_class': 3}
    num_round = 10
    bst = xgb.train(param,dtrain, num_round)
    return bst

# %%
models = []

for i in range(5):
    model_to_add = train_model_custom(fold_test_list_x[i], fold_test_list_y[i]) 
    models.append(model_to_add)

# %%
accuracy = []
for i in range(5):
    dvalid = xgb.DMatrix(fold_valid_list_x[i], label=fold_valid_list_y[i])
    pred = models[i].predict(dvalid)
    acc_score = accuracy_score(fold_valid_list_y[i], pred)
    accuracy.append(acc_score)
    print(acc_score)
# Out:
# 1.0
# 1.0
# 0.9
# 0.9
# 0.7333333333333333

# %%
total_accuracy = 0.0
for i in range(0,5):
    total_accuracy = total_accuracy + accuracy[i]

total_accuracy = total_accuracy/5
print(total_accuracy)
# Out:
# 0.9066666666666666
