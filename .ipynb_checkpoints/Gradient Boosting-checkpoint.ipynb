# %% [markdown]
# # Gradient Boosting sample code
#
# copy of gradient boosting [sample code](https://qiita.com/predora005/items/19aebcf3aa05946c7cf4)

# %% [markdown]
# ## How to use XGBoost: multi class classification using iris data
#
# XGBoost is a library using a type of decision tree algorythm, the GBDT(Gradient boosted decision tree).
# This is a guide on the installation and use of said library.
# While multiple programming languages can be used, this guide will show the use with Python.

# %% [markdown]
# ## What is GBDT
# - a type of decision tree model
# - a gradient boosted desicion tree
#
# Another famous decision tree model is the random forest, which is summarized in the article below.
# https://qiita.com/_tsuru/items/23fdc43ee0e54ec7c87e

# %% [markdown]
# ## The hallmarks of GBDT
# - easily achievable accuracy
# - can use loss function values
# - can handle numeric data
#
# Since it has a easily achievable accuracy, it's popular in the machine learning competition Kaggle.

# %% [markdown]
# ## [1] How to use
#
# We will be using the iris data set from scikit-learn. The OS used is Amazon Linux2.

# %% [markdown]
# ## [1-1] Installation
#
# In Amazon Linux2 the installation is as follows. A guide on the installation can be found on the official website.
# https://xgboost.readthedocs.io/en/latest/build.html
#
# Comment:
# type `pip3 install xgboost` into the responsible CLI.

# %% [markdown]
# ## [1-2] Import

# %%
import xgboost as xgb

# %% [markdown]
# ## [1-3] Retrieve the Iris data
#
# There are no particularities to this process. You retrieve the Iris data and create a pandas DataFrame and a Series.
#
#
# Comment:
# iris data represents the input variables, meaning the features the flower has to be able to be classified.
# iris target represents the output variables, meaning what kind of flower it is, encoded as integer.
# Basically, data is the question, target is the answer

# %%
import pandas as pd
from sklearn.datasets import load_iris

iris = load_iris()

iris_data = pd.DataFrame(iris.data, columns = iris.feature_names)
iris_target = pd.Series(iris.target)

# %% [markdown]
# ## [1-4] Create training and testing data sets
#
# There are no particularities here either, `train_test_split` from the scikit-learn package is used to split the data into training and testing data sets.

# %%
from sklearn.model_selection import train_test_split

train_x, test_x, train_y, test_y = train_test_split(iris_data, iris_target, test_size = 0.2, shuffle = True)

# %% [markdown]
# ## [1-5] Convert the data into an XGBoost data type
#
# XGBoost uses `DMatrix` data types.
#
# `DMatrix` is made up of numpy `ndarray` and pandas `DataFrame` data types, which should not pose a problem.
#
# Details on what type of data can be used can be found in the official documentation below.
# https://xgboost.readthedocs.io/en/latest/python/python_intro.html#data-interface

# %%
dtrain = xgb.DMatrix(train_x, label = train_y)

# %% [markdown]
# ## [1-6] Set Parameters
#
# Set each specific parameter.

# %%
param = {'max_depth' : 2, 'eta' : 1, 'objective': 'multi:softmax', 'num_class': 3}

# %% [markdown]
# The meaning of each parameter is as follows:
# - max_depth = how many trees will be made at a maximum
# - eta = learning rate, conrols the step size at each iteration. small nummber prevents overfitting, but requires more boosting rounds
# - objective = specifies the learning task and the corresponding learning objective
# - num_class = the number of classes
#
# The learning objective described here is "multi:softmax." To learn more about this, check the official documentation.
# https://xgboost.readthedocs.io/en/latest/parameter.html

# %% [markdown]
# ## [1-7] Training
#
# `num_round` represents the number of training rounds.

# %%
num_round = 10
bst = xgb.train(param,dtrain, num_round)

# %% [markdown]
# ## [1-8] Prediction

# %%
dtest = xgb.DMatrix(test_x)
pred = bst.predict(dtest)

# %% [markdown]
# ## [1-9] Confirming Accuaracy
#
# Confirm the accuary with scikit's `accuacy_score`.

# %%
from sklearn.metrics import accuracy_score

score = accuracy_score(test_y, pred)
print('score:{0:.4f}'.format(score))
# 0.9667
# Out:
# score:0.9667

# %% [markdown]
# ## [1-10] Plot the importance
#
# Visualize which features have contributed in what way to the predicted result.

# %%
xgb.plot_importance(bst)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ## [2] Validation and early stopping during training
#
# Validation and early stopping during the training proccess is easily accomplished by utilizing the validation data.

# %% [markdown]
# ## [2-1] Splitting the data
#
# A part of the training data is used for validation.

# %%
train_x, valid_x, train_y, valid_y = train_test_split(train_x, train_y, test_size=0.2, shuffle=True)

# %% [markdown]
# ## [2-2] Creating the DMatrix

# %%
dtrain = xgb.DMatrix(train_x, label=train_y)
dvalid = xgb.DMatrix(valid_x, label=valid_y)

# %% [markdown]
# ## [2-3] Add parameters
#
# When using validation, the "eval_metric" has to be added to the parameters. "eval_metric" defines how the result is evaluated.

# %%
param = {'max_depth': 2, 'eta': 0.5, 'objective': 'multi:softmax', 'num_class': 3, 'eval_metric': 'mlogloss'}

# %% [markdown]
# ## [2-4] Training
#
# The data to be observed is defined in "evallist." The label for the validation data is 'eval,'  for the training data 'train.'
#
# xgb.train now has the addtional parameter `early_stopping_rounds`. If the evaluation has not changed after 5 rounds, the training proccess will be cancelled an the model output.

# %%
evallist = [(dvalid, 'eval'), (dtrain, 'train')];
num_round = 10000;
bst = xgb.train(param, dtrain, num_round, evals = evallist, early_stopping_rounds=5);


# [0]   eval-mlogloss:0.61103   train-mlogloss:0.60698
# Multiple eval metrics have been passed: 'train-mlogloss' will be used for early stopping.
# 
# Will train until train-mlogloss hasn't improved in 5 rounds.
# [1]   eval-mlogloss:0.36291   train-mlogloss:0.35779
# [2]   eval-mlogloss:0.22432   train-mlogloss:0.23488
# 
# 〜〜〜 途中省略 〜〜〜
# 
# Stopping. Best iteration:
# [1153]    eval-mlogloss:0.00827   train-mlogloss:0.01863
# Out:
# [0]	eval-mlogloss:0.56606	train-mlogloss:0.57521
# [1]	eval-mlogloss:0.33534	train-mlogloss:0.35393
# [2]	eval-mlogloss:0.21388	train-mlogloss:0.23935
# [3]	eval-mlogloss:0.15083	train-mlogloss:0.17292
# [4]	eval-mlogloss:0.10871	train-mlogloss:0.12773
# [5]	eval-mlogloss:0.07959	train-mlogloss:0.10008
# [6]	eval-mlogloss:0.06450	train-mlogloss:0.08355
# [7]	eval-mlogloss:0.05388	train-mlogloss:0.07056
# [8]	eval-mlogloss:0.04917	train-mlogloss:0.06183
# [9]	eval-mlogloss:0.04530	train-mlogloss:0.05365
# [10]	eval-mlogloss:0.03671	train-mlogloss:0.04859
# [11]	eval-mlogloss:0.03570	train-mlogloss:0.04551
# [12]	eval-mlogloss:0.03234	train-mlogloss:0.04318
# [13]	eval-mlogloss:0.03033	train-mlogloss:0.04032
# [14]	eval-mlogloss:0.03158	train-mlogloss:0.03817
# [15]	eval-mlogloss:0.03052	train-mlogloss:0.03664
# [16]	eval-mlogloss:0.03218	train-mlogloss:0.03504
# [17]	eval-mlogloss:0.02981	train-mlogloss:0.03371
# [18]	eval-mlogloss:0.02927	train-mlogloss:0.03263
# [19]	eval-mlogloss:0.02983	train-mlogloss:0.03131
# [20]	eval-mlogloss:0.02934	train-mlogloss:0.03032
# [21]	eval-mlogloss:0.02947	train-mlogloss:0.02969
# [22]	eval-mlogloss:0.02913	train-mlogloss:0.02879
# [23]	eval-mlogloss:0.02885	train-mlogloss:0.02839
# [24]	eval-mlogloss:0.02983	train-mlogloss:0.02778
# [25]	eval-mlogloss:0.02818	train-mlogloss:0.02715
# [26]	eval-mlogloss:0.02789	train-mlogloss:0.02676
# [27]	eval-mlogloss:0.02936	train-mlogloss:0.02636
# [28]	eval-mlogloss:0.02795	train-mlogloss:0.02600
# [29]	eval-mlogloss:0.02779	train-mlogloss:0.02548
# [30]	eval-mlogloss:0.02656	train-mlogloss:0.02517
# [31]	eval-mlogloss:0.02674	train-mlogloss:0.02468
# [32]	eval-mlogloss:0.02649	train-mlogloss:0.02435
# [33]	eval-mlogloss:0.02543	train-mlogloss:0.02387
# [34]	eval-mlogloss:0.02524	train-mlogloss:0.02359
# [35]	eval-mlogloss:0.02638	train-mlogloss:0.02328
# [36]	eval-mlogloss:0.02519	train-mlogloss:0.02300
# [37]	eval-mlogloss:0.02511	train-mlogloss:0.02261
# [38]	eval-mlogloss:0.02396	train-mlogloss:0.02239
# [39]	eval-mlogloss:0.02391	train-mlogloss:0.02205
# [40]	eval-mlogloss:0.02461	train-mlogloss:0.02185
# [41]	eval-mlogloss:0.02372	train-mlogloss:0.02166
# [42]	eval-mlogloss:0.02351	train-mlogloss:0.02145
# [43]	eval-mlogloss:0.02331	train-mlogloss:0.02125
# [44]	eval-mlogloss:0.02379	train-mlogloss:0.02107
# [45]	eval-mlogloss:0.02285	train-mlogloss:0.02089
# [46]	eval-mlogloss:0.02261	train-mlogloss:0.02072
# [47]	eval-mlogloss:0.02241	train-mlogloss:0.02054
# [48]	eval-mlogloss:0.02220	train-mlogloss:0.02038
# [49]	eval-mlogloss:0.02142	train-mlogloss:0.02021
# [50]	eval-mlogloss:0.02184	train-mlogloss:0.02006
# [51]	eval-mlogloss:0.02112	train-mlogloss:0.01991
# [52]	eval-mlogloss:0.02153	train-mlogloss:0.01976
# [53]	eval-mlogloss:0.02075	train-mlogloss:0.01962
# [54]	eval-mlogloss:0.02056	train-mlogloss:0.01949
# [55]	eval-mlogloss:0.01991	train-mlogloss:0.01935
# [56]	eval-mlogloss:0.02028	train-mlogloss:0.01922
# [57]	eval-mlogloss:0.01968	train-mlogloss:0.01910
# [58]	eval-mlogloss:0.01909	train-mlogloss:0.01899
# [59]	eval-mlogloss:0.01895	train-mlogloss:0.01885
# [60]	eval-mlogloss:0.01837	train-mlogloss:0.01875
# [61]	eval-mlogloss:0.01841	train-mlogloss:0.01863
# [62]	eval-mlogloss:0.01790	train-mlogloss:0.01854
# [63]	eval-mlogloss:0.01737	train-mlogloss:0.01847
# [64]	eval-mlogloss:0.01737	train-mlogloss:0.01834
# [65]	eval-mlogloss:0.01699	train-mlogloss:0.01827
# [66]	eval-mlogloss:0.01655	train-mlogloss:0.01821
# [67]	eval-mlogloss:0.01620	train-mlogloss:0.01816
# [68]	eval-mlogloss:0.01616	train-mlogloss:0.01803
# [69]	eval-mlogloss:0.01600	train-mlogloss:0.01799
# [70]	eval-mlogloss:0.01580	train-mlogloss:0.01795
# [71]	eval-mlogloss:0.01562	train-mlogloss:0.01792
# [72]	eval-mlogloss:0.01540	train-mlogloss:0.01789
# [73]	eval-mlogloss:0.01529	train-mlogloss:0.01786
# [74]	eval-mlogloss:0.01514	train-mlogloss:0.01783
# [75]	eval-mlogloss:0.01495	train-mlogloss:0.01781
# [76]	eval-mlogloss:0.01487	train-mlogloss:0.01778
# [77]	eval-mlogloss:0.01474	train-mlogloss:0.01776
# [78]	eval-mlogloss:0.01458	train-mlogloss:0.01774
# [79]	eval-mlogloss:0.01445	train-mlogloss:0.01772
# [80]	eval-mlogloss:0.01434	train-mlogloss:0.01770
# [81]	eval-mlogloss:0.01418	train-mlogloss:0.01768
# [82]	eval-mlogloss:0.01407	train-mlogloss:0.01766
# [83]	eval-mlogloss:0.01393	train-mlogloss:0.01764
# [84]	eval-mlogloss:0.01383	train-mlogloss:0.01762
# [85]	eval-mlogloss:0.01373	train-mlogloss:0.01761
# [86]	eval-mlogloss:0.01360	train-mlogloss:0.01759
# [87]	eval-mlogloss:0.01351	train-mlogloss:0.01758
# [88]	eval-mlogloss:0.01358	train-mlogloss:0.01746
# [89]	eval-mlogloss:0.01346	train-mlogloss:0.01743
# [90]	eval-mlogloss:0.01336	train-mlogloss:0.01742
# [91]	eval-mlogloss:0.01331	train-mlogloss:0.01740
# [92]	eval-mlogloss:0.01322	train-mlogloss:0.01739
# [93]	eval-mlogloss:0.01313	train-mlogloss:0.01737
# [94]	eval-mlogloss:0.01306	train-mlogloss:0.01736
# [95]	eval-mlogloss:0.01295	train-mlogloss:0.01735
# [96]	eval-mlogloss:0.01287	train-mlogloss:0.01734
# [97]	eval-mlogloss:0.01277	train-mlogloss:0.01732
# [98]	eval-mlogloss:0.01270	train-mlogloss:0.01731
# [99]	eval-mlogloss:0.01263	train-mlogloss:0.01730
# [100]	eval-mlogloss:0.01254	train-mlogloss:0.01729
# [101]	eval-mlogloss:0.01247	train-mlogloss:0.01728
# [102]	eval-mlogloss:0.01239	train-mlogloss:0.01727
# [103]	eval-mlogloss:0.01232	train-mlogloss:0.01726
# [104]	eval-mlogloss:0.01227	train-mlogloss:0.01725
# [105]	eval-mlogloss:0.01231	train-mlogloss:0.01724
# [106]	eval-mlogloss:0.01234	train-mlogloss:0.01723
# [107]	eval-mlogloss:0.01227	train-mlogloss:0.01722
# [108]	eval-mlogloss:0.01218	train-mlogloss:0.01722
# [109]	eval-mlogloss:0.01221	train-mlogloss:0.01721
# [110]	eval-mlogloss:0.01215	train-mlogloss:0.01720
# [111]	eval-mlogloss:0.01218	train-mlogloss:0.01719
# [112]	eval-mlogloss:0.01210	train-mlogloss:0.01718
# [113]	eval-mlogloss:0.01204	train-mlogloss:0.01717
# [114]	eval-mlogloss:0.01207	train-mlogloss:0.01716
# [115]	eval-mlogloss:0.01204	train-mlogloss:0.01715
# [116]	eval-mlogloss:0.01208	train-mlogloss:0.01715
# [117]	eval-mlogloss:0.01200	train-mlogloss:0.01714
# [118]	eval-mlogloss:0.01194	train-mlogloss:0.01713
# [119]	eval-mlogloss:0.01198	train-mlogloss:0.01712
# [120]	eval-mlogloss:0.01190	train-mlogloss:0.01711
# [121]	eval-mlogloss:0.01184	train-mlogloss:0.01711
# [122]	eval-mlogloss:0.01188	train-mlogloss:0.01710
# [123]	eval-mlogloss:0.01183	train-mlogloss:0.01709
# [124]	eval-mlogloss:0.01186	train-mlogloss:0.01708
# [125]	eval-mlogloss:0.01178	train-mlogloss:0.01708
# [126]	eval-mlogloss:0.01176	train-mlogloss:0.01707
# [127]	eval-mlogloss:0.01179	train-mlogloss:0.01706
# [128]	eval-mlogloss:0.01174	train-mlogloss:0.01706
# [129]	eval-mlogloss:0.01167	train-mlogloss:0.01705
# [130]	eval-mlogloss:0.01171	train-mlogloss:0.01704
# [131]	eval-mlogloss:0.01165	train-mlogloss:0.01703
# [132]	eval-mlogloss:0.01168	train-mlogloss:0.01703
# [133]	eval-mlogloss:0.01162	train-mlogloss:0.01702
# [134]	eval-mlogloss:0.01157	train-mlogloss:0.01702
# [135]	eval-mlogloss:0.01160	train-mlogloss:0.01701
# [136]	eval-mlogloss:0.01154	train-mlogloss:0.01700
# [137]	eval-mlogloss:0.01149	train-mlogloss:0.01700
# [138]	eval-mlogloss:0.01152	train-mlogloss:0.01699
# [139]	eval-mlogloss:0.01150	train-mlogloss:0.01698
# [140]	eval-mlogloss:0.01153	train-mlogloss:0.01698
# [141]	eval-mlogloss:0.01147	train-mlogloss:0.01697
# [142]	eval-mlogloss:0.01142	train-mlogloss:0.01697
# [143]	eval-mlogloss:0.01145	train-mlogloss:0.01696
# [144]	eval-mlogloss:0.01141	train-mlogloss:0.01696
# [145]	eval-mlogloss:0.01143	train-mlogloss:0.01695
# [146]	eval-mlogloss:0.01137	train-mlogloss:0.01695
# [147]	eval-mlogloss:0.01133	train-mlogloss:0.01694
# [148]	eval-mlogloss:0.01136	train-mlogloss:0.01693
# [149]	eval-mlogloss:0.01130	train-mlogloss:0.01693
# [150]	eval-mlogloss:0.01126	train-mlogloss:0.01692
# [151]	eval-mlogloss:0.01129	train-mlogloss:0.01692
# [152]	eval-mlogloss:0.01123	train-mlogloss:0.01691
# [153]	eval-mlogloss:0.01122	train-mlogloss:0.01691
# [154]	eval-mlogloss:0.01125	train-mlogloss:0.01691
# [155]	eval-mlogloss:0.01121	train-mlogloss:0.01690
# [156]	eval-mlogloss:0.01115	train-mlogloss:0.01690
# [157]	eval-mlogloss:0.01118	train-mlogloss:0.01689
# [158]	eval-mlogloss:0.01114	train-mlogloss:0.01689
# [159]	eval-mlogloss:0.01108	train-mlogloss:0.01688
# [160]	eval-mlogloss:0.01111	train-mlogloss:0.01688
# [161]	eval-mlogloss:0.01110	train-mlogloss:0.01687
# [162]	eval-mlogloss:0.01105	train-mlogloss:0.01687
# [163]	eval-mlogloss:0.01101	train-mlogloss:0.01686
# [164]	eval-mlogloss:0.01104	train-mlogloss:0.01686
# [165]	eval-mlogloss:0.01103	train-mlogloss:0.01686
# [166]	eval-mlogloss:0.01105	train-mlogloss:0.01685
# [167]	eval-mlogloss:0.01100	train-mlogloss:0.01685
# [168]	eval-mlogloss:0.01099	train-mlogloss:0.01684
# [169]	eval-mlogloss:0.01095	train-mlogloss:0.01684
# [170]	eval-mlogloss:0.01094	train-mlogloss:0.01684
# [171]	eval-mlogloss:0.01090	train-mlogloss:0.01683
# [172]	eval-mlogloss:0.01087	train-mlogloss:0.01683
# [173]	eval-mlogloss:0.01083	train-mlogloss:0.01682
# [174]	eval-mlogloss:0.01086	train-mlogloss:0.01682
# [175]	eval-mlogloss:0.01081	train-mlogloss:0.01682
# [176]	eval-mlogloss:0.01081	train-mlogloss:0.01681
# [177]	eval-mlogloss:0.01076	train-mlogloss:0.01681
# [178]	eval-mlogloss:0.01076	train-mlogloss:0.01680
# [179]	eval-mlogloss:0.01078	train-mlogloss:0.01680
# [180]	eval-mlogloss:0.01075	train-mlogloss:0.01680
# [181]	eval-mlogloss:0.01071	train-mlogloss:0.01679
# [182]	eval-mlogloss:0.01073	train-mlogloss:0.01679
# [183]	eval-mlogloss:0.01070	train-mlogloss:0.01679
# [184]	eval-mlogloss:0.01065	train-mlogloss:0.01678
# [185]	eval-mlogloss:0.01067	train-mlogloss:0.01678
# [186]	eval-mlogloss:0.01066	train-mlogloss:0.01678
# [187]	eval-mlogloss:0.01062	train-mlogloss:0.01677
# [188]	eval-mlogloss:0.01059	train-mlogloss:0.01677
# [189]	eval-mlogloss:0.01062	train-mlogloss:0.01676
# [190]	eval-mlogloss:0.01058	train-mlogloss:0.01676
# [191]	eval-mlogloss:0.01057	train-mlogloss:0.01676
# [192]	eval-mlogloss:0.01053	train-mlogloss:0.01675
# [193]	eval-mlogloss:0.01053	train-mlogloss:0.01675
# [194]	eval-mlogloss:0.01055	train-mlogloss:0.01675
# [195]	eval-mlogloss:0.01052	train-mlogloss:0.01675
# [196]	eval-mlogloss:0.01048	train-mlogloss:0.01674
# [197]	eval-mlogloss:0.01050	train-mlogloss:0.01674
# [198]	eval-mlogloss:0.01047	train-mlogloss:0.01674
# [199]	eval-mlogloss:0.01043	train-mlogloss:0.01673
# [200]	eval-mlogloss:0.01043	train-mlogloss:0.01673
# [201]	eval-mlogloss:0.01045	train-mlogloss:0.01673
# [202]	eval-mlogloss:0.01041	train-mlogloss:0.01672
# [203]	eval-mlogloss:0.01038	train-mlogloss:0.01672
# [204]	eval-mlogloss:0.01040	train-mlogloss:0.01672
# [205]	eval-mlogloss:0.01039	train-mlogloss:0.01671
# [206]	eval-mlogloss:0.01036	train-mlogloss:0.01671
# [207]	eval-mlogloss:0.01035	train-mlogloss:0.01671
# [208]	eval-mlogloss:0.01037	train-mlogloss:0.01671
# [209]	eval-mlogloss:0.01034	train-mlogloss:0.01670
# [210]	eval-mlogloss:0.01031	train-mlogloss:0.01670
# [211]	eval-mlogloss:0.01033	train-mlogloss:0.01670
# [212]	eval-mlogloss:0.01032	train-mlogloss:0.01669
# [213]	eval-mlogloss:0.01029	train-mlogloss:0.01669
# [214]	eval-mlogloss:0.01026	train-mlogloss:0.01669
# [215]	eval-mlogloss:0.01024	train-mlogloss:0.01669
# [216]	eval-mlogloss:0.01020	train-mlogloss:0.01668
# [217]	eval-mlogloss:0.01020	train-mlogloss:0.01668
# [218]	eval-mlogloss:0.01017	train-mlogloss:0.01668
# [219]	eval-mlogloss:0.01019	train-mlogloss:0.01668
# [220]	eval-mlogloss:0.01018	train-mlogloss:0.01667
# [221]	eval-mlogloss:0.01015	train-mlogloss:0.01667
# [222]	eval-mlogloss:0.01013	train-mlogloss:0.01667
# [223]	eval-mlogloss:0.01014	train-mlogloss:0.01667
# [224]	eval-mlogloss:0.01011	train-mlogloss:0.01666
# [225]	eval-mlogloss:0.01011	train-mlogloss:0.01666
# [226]	eval-mlogloss:0.01008	train-mlogloss:0.01666
# [227]	eval-mlogloss:0.01008	train-mlogloss:0.01666
# [228]	eval-mlogloss:0.01010	train-mlogloss:0.01665
# [229]	eval-mlogloss:0.01007	train-mlogloss:0.01665
# [230]	eval-mlogloss:0.01004	train-mlogloss:0.01665
# [231]	eval-mlogloss:0.01005	train-mlogloss:0.01665
# [232]	eval-mlogloss:0.01003	train-mlogloss:0.01664
# [233]	eval-mlogloss:0.01000	train-mlogloss:0.01664
# [234]	eval-mlogloss:0.01000	train-mlogloss:0.01664
# [235]	eval-mlogloss:0.01001	train-mlogloss:0.01664
# [236]	eval-mlogloss:0.00998	train-mlogloss:0.01664
# [237]	eval-mlogloss:0.00996	train-mlogloss:0.01663
# [238]	eval-mlogloss:0.00998	train-mlogloss:0.01663
# [239]	eval-mlogloss:0.00997	train-mlogloss:0.01663
# [240]	eval-mlogloss:0.00994	train-mlogloss:0.01663
# [241]	eval-mlogloss:0.00994	train-mlogloss:0.01662
# [242]	eval-mlogloss:0.00996	train-mlogloss:0.01662
# [243]	eval-mlogloss:0.00993	train-mlogloss:0.01662
# [244]	eval-mlogloss:0.00991	train-mlogloss:0.01662
# [245]	eval-mlogloss:0.00992	train-mlogloss:0.01662
# [246]	eval-mlogloss:0.00992	train-mlogloss:0.01661
# [247]	eval-mlogloss:0.00989	train-mlogloss:0.01661
# [248]	eval-mlogloss:0.00987	train-mlogloss:0.01661
# [249]	eval-mlogloss:0.00984	train-mlogloss:0.01661
# [250]	eval-mlogloss:0.00984	train-mlogloss:0.01661
# [251]	eval-mlogloss:0.00986	train-mlogloss:0.01660
# [252]	eval-mlogloss:0.00983	train-mlogloss:0.01660
# [253]	eval-mlogloss:0.00983	train-mlogloss:0.01660
# [254]	eval-mlogloss:0.00980	train-mlogloss:0.01660
# [255]	eval-mlogloss:0.00978	train-mlogloss:0.01660
# [256]	eval-mlogloss:0.00980	train-mlogloss:0.01659
# [257]	eval-mlogloss:0.00980	train-mlogloss:0.01659
# [258]	eval-mlogloss:0.00977	train-mlogloss:0.01659
# [259]	eval-mlogloss:0.00975	train-mlogloss:0.01659
# [260]	eval-mlogloss:0.00968	train-mlogloss:0.01658
# [261]	eval-mlogloss:0.00965	train-mlogloss:0.01658
# [262]	eval-mlogloss:0.00961	train-mlogloss:0.01657
# [263]	eval-mlogloss:0.00954	train-mlogloss:0.01656
# [264]	eval-mlogloss:0.00951	train-mlogloss:0.01656
# [265]	eval-mlogloss:0.00945	train-mlogloss:0.01655
# [266]	eval-mlogloss:0.00943	train-mlogloss:0.01655
# [267]	eval-mlogloss:0.00937	train-mlogloss:0.01654
# [268]	eval-mlogloss:0.00931	train-mlogloss:0.01654
# [269]	eval-mlogloss:0.00930	train-mlogloss:0.01653
# [270]	eval-mlogloss:0.00925	train-mlogloss:0.01653
# [271]	eval-mlogloss:0.00923	train-mlogloss:0.01652
# [272]	eval-mlogloss:0.00919	train-mlogloss:0.01652
# [273]	eval-mlogloss:0.00918	train-mlogloss:0.01652
# [274]	eval-mlogloss:0.00914	train-mlogloss:0.01652
# [275]	eval-mlogloss:0.00912	train-mlogloss:0.01651
# [276]	eval-mlogloss:0.00908	train-mlogloss:0.01651
# [277]	eval-mlogloss:0.00908	train-mlogloss:0.01651
# [278]	eval-mlogloss:0.00904	train-mlogloss:0.01650
# [279]	eval-mlogloss:0.00903	train-mlogloss:0.01650
# [280]	eval-mlogloss:0.00903	train-mlogloss:0.01650
# [281]	eval-mlogloss:0.00899	train-mlogloss:0.01650
# [282]	eval-mlogloss:0.00899	train-mlogloss:0.01649
# [283]	eval-mlogloss:0.00896	train-mlogloss:0.01649
# [284]	eval-mlogloss:0.00895	train-mlogloss:0.01649
# [285]	eval-mlogloss:0.00892	train-mlogloss:0.01649
# [286]	eval-mlogloss:0.00892	train-mlogloss:0.01648
# [287]	eval-mlogloss:0.00889	train-mlogloss:0.01648
# [288]	eval-mlogloss:0.00888	train-mlogloss:0.01648
# [289]	eval-mlogloss:0.00886	train-mlogloss:0.01648
# [290]	eval-mlogloss:0.00886	train-mlogloss:0.01648
# [291]	eval-mlogloss:0.00885	train-mlogloss:0.01647
# [292]	eval-mlogloss:0.00883	train-mlogloss:0.01647
# [293]	eval-mlogloss:0.00884	train-mlogloss:0.01647
# [294]	eval-mlogloss:0.00881	train-mlogloss:0.01647
# [295]	eval-mlogloss:0.00880	train-mlogloss:0.01646
# [296]	eval-mlogloss:0.00878	train-mlogloss:0.01646
# [297]	eval-mlogloss:0.00878	train-mlogloss:0.01646
# [298]	eval-mlogloss:0.00878	train-mlogloss:0.01646
# [299]	eval-mlogloss:0.00876	train-mlogloss:0.01646
# [300]	eval-mlogloss:0.00876	train-mlogloss:0.01645
# [301]	eval-mlogloss:0.00876	train-mlogloss:0.01645
# [302]	eval-mlogloss:0.00874	train-mlogloss:0.01645
# [303]	eval-mlogloss:0.00871	train-mlogloss:0.01645
# [304]	eval-mlogloss:0.00871	train-mlogloss:0.01645
# [305]	eval-mlogloss:0.00872	train-mlogloss:0.01645
# [306]	eval-mlogloss:0.00870	train-mlogloss:0.01644
# [307]	eval-mlogloss:0.00869	train-mlogloss:0.01644
# [308]	eval-mlogloss:0.00867	train-mlogloss:0.01644
# [309]	eval-mlogloss:0.00868	train-mlogloss:0.01644
# [310]	eval-mlogloss:0.00867	train-mlogloss:0.01644
# [311]	eval-mlogloss:0.00865	train-mlogloss:0.01643
# [312]	eval-mlogloss:0.00866	train-mlogloss:0.01643
# [313]	eval-mlogloss:0.00864	train-mlogloss:0.01643
# [314]	eval-mlogloss:0.00863	train-mlogloss:0.01643
# [315]	eval-mlogloss:0.00862	train-mlogloss:0.01643
# [316]	eval-mlogloss:0.00861	train-mlogloss:0.01643
# [317]	eval-mlogloss:0.00860	train-mlogloss:0.01643
# [318]	eval-mlogloss:0.00860	train-mlogloss:0.01642
# [319]	eval-mlogloss:0.00860	train-mlogloss:0.01642
# [320]	eval-mlogloss:0.00858	train-mlogloss:0.01642
# [321]	eval-mlogloss:0.00859	train-mlogloss:0.01642
# [322]	eval-mlogloss:0.00857	train-mlogloss:0.01642
# [323]	eval-mlogloss:0.00856	train-mlogloss:0.01642
# [324]	eval-mlogloss:0.00854	train-mlogloss:0.01641
# [325]	eval-mlogloss:0.00854	train-mlogloss:0.01641
# [326]	eval-mlogloss:0.00855	train-mlogloss:0.01641
# [327]	eval-mlogloss:0.00853	train-mlogloss:0.01641
# [328]	eval-mlogloss:0.00853	train-mlogloss:0.01641
# [329]	eval-mlogloss:0.00852	train-mlogloss:0.01641
# [330]	eval-mlogloss:0.00853	train-mlogloss:0.01641
# [331]	eval-mlogloss:0.00851	train-mlogloss:0.01640
# [332]	eval-mlogloss:0.00850	train-mlogloss:0.01640
# [333]	eval-mlogloss:0.00849	train-mlogloss:0.01640
# [334]	eval-mlogloss:0.00849	train-mlogloss:0.01640
# [335]	eval-mlogloss:0.00849	train-mlogloss:0.01640
# [336]	eval-mlogloss:0.00848	train-mlogloss:0.01640
# [337]	eval-mlogloss:0.00848	train-mlogloss:0.01640
# [338]	eval-mlogloss:0.00847	train-mlogloss:0.01639
# [339]	eval-mlogloss:0.00848	train-mlogloss:0.01639
# [340]	eval-mlogloss:0.00846	train-mlogloss:0.01639
# [341]	eval-mlogloss:0.00846	train-mlogloss:0.01639
# [342]	eval-mlogloss:0.00845	train-mlogloss:0.01639
# [343]	eval-mlogloss:0.00845	train-mlogloss:0.01639
# [344]	eval-mlogloss:0.00843	train-mlogloss:0.01639
# [345]	eval-mlogloss:0.00844	train-mlogloss:0.01639
# [346]	eval-mlogloss:0.00843	train-mlogloss:0.01638
# [347]	eval-mlogloss:0.00843	train-mlogloss:0.01638
# [348]	eval-mlogloss:0.00843	train-mlogloss:0.01638
# [349]	eval-mlogloss:0.00843	train-mlogloss:0.01638
# [350]	eval-mlogloss:0.00841	train-mlogloss:0.01638
# [351]	eval-mlogloss:0.00840	train-mlogloss:0.01638
# [352]	eval-mlogloss:0.00840	train-mlogloss:0.01638
# [353]	eval-mlogloss:0.00839	train-mlogloss:0.01638
# [354]	eval-mlogloss:0.00840	train-mlogloss:0.01637
# [355]	eval-mlogloss:0.00840	train-mlogloss:0.01637
# [356]	eval-mlogloss:0.00838	train-mlogloss:0.01637
# [357]	eval-mlogloss:0.00838	train-mlogloss:0.01637
# [358]	eval-mlogloss:0.00837	train-mlogloss:0.01637
# [359]	eval-mlogloss:0.00838	train-mlogloss:0.01637
# [360]	eval-mlogloss:0.00838	train-mlogloss:0.01637
# [361]	eval-mlogloss:0.00836	train-mlogloss:0.01637
# [362]	eval-mlogloss:0.00835	train-mlogloss:0.01636
# [363]	eval-mlogloss:0.00835	train-mlogloss:0.01636
# [364]	eval-mlogloss:0.00834	train-mlogloss:0.01636
# [365]	eval-mlogloss:0.00835	train-mlogloss:0.01636
# [366]	eval-mlogloss:0.00834	train-mlogloss:0.01636
# [367]	eval-mlogloss:0.00833	train-mlogloss:0.01636
# [368]	eval-mlogloss:0.00833	train-mlogloss:0.01636
# [369]	eval-mlogloss:0.00832	train-mlogloss:0.01636
# [370]	eval-mlogloss:0.00833	train-mlogloss:0.01636
# [371]	eval-mlogloss:0.00832	train-mlogloss:0.01635
# [372]	eval-mlogloss:0.00831	train-mlogloss:0.01635
# [373]	eval-mlogloss:0.00830	train-mlogloss:0.01635
# [374]	eval-mlogloss:0.00830	train-mlogloss:0.01635
# [375]	eval-mlogloss:0.00829	train-mlogloss:0.01635
# [376]	eval-mlogloss:0.00829	train-mlogloss:0.01635
# [377]	eval-mlogloss:0.00830	train-mlogloss:0.01635
# [378]	eval-mlogloss:0.00828	train-mlogloss:0.01635
# [379]	eval-mlogloss:0.00828	train-mlogloss:0.01635
# [380]	eval-mlogloss:0.00828	train-mlogloss:0.01634
# [381]	eval-mlogloss:0.00828	train-mlogloss:0.01634
# [382]	eval-mlogloss:0.00828	train-mlogloss:0.01634
# [383]	eval-mlogloss:0.00827	train-mlogloss:0.01634
# [384]	eval-mlogloss:0.00825	train-mlogloss:0.01634
# [385]	eval-mlogloss:0.00825	train-mlogloss:0.01634
# [386]	eval-mlogloss:0.00825	train-mlogloss:0.01634
# [387]	eval-mlogloss:0.00825	train-mlogloss:0.01634
# [388]	eval-mlogloss:0.00823	train-mlogloss:0.01634
# [389]	eval-mlogloss:0.00824	train-mlogloss:0.01634
# [390]	eval-mlogloss:0.00824	train-mlogloss:0.01633
# [391]	eval-mlogloss:0.00823	train-mlogloss:0.01633
# [392]	eval-mlogloss:0.00823	train-mlogloss:0.01633
# [393]	eval-mlogloss:0.00822	train-mlogloss:0.01633
# [394]	eval-mlogloss:0.00823	train-mlogloss:0.01633
# [395]	eval-mlogloss:0.00823	train-mlogloss:0.01633
# [396]	eval-mlogloss:0.00821	train-mlogloss:0.01633
# [397]	eval-mlogloss:0.00820	train-mlogloss:0.01633
# [398]	eval-mlogloss:0.00820	train-mlogloss:0.01633
# [399]	eval-mlogloss:0.00819	train-mlogloss:0.01633
# [400]	eval-mlogloss:0.00819	train-mlogloss:0.01632
# [401]	eval-mlogloss:0.00818	train-mlogloss:0.01632
# [402]	eval-mlogloss:0.00818	train-mlogloss:0.01632
# [403]	eval-mlogloss:0.00818	train-mlogloss:0.01632
# [404]	eval-mlogloss:0.00818	train-mlogloss:0.01632
# [405]	eval-mlogloss:0.00818	train-mlogloss:0.01632
# [406]	eval-mlogloss:0.00816	train-mlogloss:0.01632
# [407]	eval-mlogloss:0.00817	train-mlogloss:0.01632
# [408]	eval-mlogloss:0.00817	train-mlogloss:0.01632
# [409]	eval-mlogloss:0.00816	train-mlogloss:0.01632
# [410]	eval-mlogloss:0.00816	train-mlogloss:0.01631
# [411]	eval-mlogloss:0.00815	train-mlogloss:0.01631
# [412]	eval-mlogloss:0.00816	train-mlogloss:0.01631
# [413]	eval-mlogloss:0.00814	train-mlogloss:0.01631
# [414]	eval-mlogloss:0.00814	train-mlogloss:0.01631
# [415]	eval-mlogloss:0.00813	train-mlogloss:0.01631
# [416]	eval-mlogloss:0.00813	train-mlogloss:0.01631
# [417]	eval-mlogloss:0.00812	train-mlogloss:0.01631
# [418]	eval-mlogloss:0.00812	train-mlogloss:0.01631
# [419]	eval-mlogloss:0.00811	train-mlogloss:0.01631
# [420]	eval-mlogloss:0.00812	train-mlogloss:0.01631
# [421]	eval-mlogloss:0.00812	train-mlogloss:0.01630
# [422]	eval-mlogloss:0.00811	train-mlogloss:0.01630
# [423]	eval-mlogloss:0.00811	train-mlogloss:0.01630
# [424]	eval-mlogloss:0.00810	train-mlogloss:0.01630
# [425]	eval-mlogloss:0.00810	train-mlogloss:0.01630
# [426]	eval-mlogloss:0.00810	train-mlogloss:0.01630
# [427]	eval-mlogloss:0.00809	train-mlogloss:0.01630
# [428]	eval-mlogloss:0.00808	train-mlogloss:0.01630
# [429]	eval-mlogloss:0.00808	train-mlogloss:0.01630
# [430]	eval-mlogloss:0.00807	train-mlogloss:0.01630
# [431]	eval-mlogloss:0.00807	train-mlogloss:0.01630
# [432]	eval-mlogloss:0.00807	train-mlogloss:0.01630
# [433]	eval-mlogloss:0.00807	train-mlogloss:0.01629
# [434]	eval-mlogloss:0.00806	train-mlogloss:0.01629
# [435]	eval-mlogloss:0.00806	train-mlogloss:0.01629
# [436]	eval-mlogloss:0.00806	train-mlogloss:0.01629
# [437]	eval-mlogloss:0.00805	train-mlogloss:0.01629
# [438]	eval-mlogloss:0.00805	train-mlogloss:0.01629
# [439]	eval-mlogloss:0.00804	train-mlogloss:0.01629
# [440]	eval-mlogloss:0.00805	train-mlogloss:0.01629
# [441]	eval-mlogloss:0.00805	train-mlogloss:0.01629
# [442]	eval-mlogloss:0.00804	train-mlogloss:0.01629
# [443]	eval-mlogloss:0.00804	train-mlogloss:0.01629
# [444]	eval-mlogloss:0.00803	train-mlogloss:0.01629
# [445]	eval-mlogloss:0.00802	train-mlogloss:0.01628
# [446]	eval-mlogloss:0.00802	train-mlogloss:0.01628
# [447]	eval-mlogloss:0.00801	train-mlogloss:0.01628
# [448]	eval-mlogloss:0.00802	train-mlogloss:0.01628
# [449]	eval-mlogloss:0.00800	train-mlogloss:0.01628
# [450]	eval-mlogloss:0.00801	train-mlogloss:0.01628
# [451]	eval-mlogloss:0.00801	train-mlogloss:0.01628
# [452]	eval-mlogloss:0.00800	train-mlogloss:0.01628
# [453]	eval-mlogloss:0.00800	train-mlogloss:0.01628
# [454]	eval-mlogloss:0.00799	train-mlogloss:0.01628
# [455]	eval-mlogloss:0.00800	train-mlogloss:0.01628
# [456]	eval-mlogloss:0.00798	train-mlogloss:0.01628
# [457]	eval-mlogloss:0.00799	train-mlogloss:0.01628
# [458]	eval-mlogloss:0.00799	train-mlogloss:0.01627
# [459]	eval-mlogloss:0.00798	train-mlogloss:0.01627
# [460]	eval-mlogloss:0.00798	train-mlogloss:0.01627
# [461]	eval-mlogloss:0.00797	train-mlogloss:0.01627
# [462]	eval-mlogloss:0.00798	train-mlogloss:0.01627
# [463]	eval-mlogloss:0.00798	train-mlogloss:0.01627
# [464]	eval-mlogloss:0.00797	train-mlogloss:0.01627
# [465]	eval-mlogloss:0.00797	train-mlogloss:0.01627
# [466]	eval-mlogloss:0.00796	train-mlogloss:0.01627
# [467]	eval-mlogloss:0.00796	train-mlogloss:0.01627
# [468]	eval-mlogloss:0.00796	train-mlogloss:0.01627
# [469]	eval-mlogloss:0.00796	train-mlogloss:0.01627
# [470]	eval-mlogloss:0.00796	train-mlogloss:0.01627
# [471]	eval-mlogloss:0.00795	train-mlogloss:0.01627
# [472]	eval-mlogloss:0.00794	train-mlogloss:0.01626
# [473]	eval-mlogloss:0.00794	train-mlogloss:0.01626
# [474]	eval-mlogloss:0.00795	train-mlogloss:0.01626
# [475]	eval-mlogloss:0.00795	train-mlogloss:0.01626
# [476]	eval-mlogloss:0.00794	train-mlogloss:0.01626
# [477]	eval-mlogloss:0.00794	train-mlogloss:0.01626
# [478]	eval-mlogloss:0.00793	train-mlogloss:0.01626
# [479]	eval-mlogloss:0.00794	train-mlogloss:0.01626
# [480]	eval-mlogloss:0.00794	train-mlogloss:0.01626
# [481]	eval-mlogloss:0.00792	train-mlogloss:0.01626
# [482]	eval-mlogloss:0.00791	train-mlogloss:0.01626
# [483]	eval-mlogloss:0.00791	train-mlogloss:0.01626
# [484]	eval-mlogloss:0.00792	train-mlogloss:0.01626
# [485]	eval-mlogloss:0.00792	train-mlogloss:0.01626
# [486]	eval-mlogloss:0.00791	train-mlogloss:0.01625
# [487]	eval-mlogloss:0.00790	train-mlogloss:0.01625
# [488]	eval-mlogloss:0.00791	train-mlogloss:0.01625
# [489]	eval-mlogloss:0.00791	train-mlogloss:0.01625
# [490]	eval-mlogloss:0.00791	train-mlogloss:0.01625
# [491]	eval-mlogloss:0.00790	train-mlogloss:0.01625
# [492]	eval-mlogloss:0.00789	train-mlogloss:0.01625
# [493]	eval-mlogloss:0.00789	train-mlogloss:0.01625
# [494]	eval-mlogloss:0.00790	train-mlogloss:0.01625
# [495]	eval-mlogloss:0.00790	train-mlogloss:0.01625
# [496]	eval-mlogloss:0.00789	train-mlogloss:0.01625
# [497]	eval-mlogloss:0.00788	train-mlogloss:0.01625
# [498]	eval-mlogloss:0.00788	train-mlogloss:0.01625
# [499]	eval-mlogloss:0.00789	train-mlogloss:0.01625
# [500]	eval-mlogloss:0.00789	train-mlogloss:0.01624
# [501]	eval-mlogloss:0.00788	train-mlogloss:0.01624
# [502]	eval-mlogloss:0.00788	train-mlogloss:0.01624
# [503]	eval-mlogloss:0.00787	train-mlogloss:0.01624
# [504]	eval-mlogloss:0.00787	train-mlogloss:0.01624
# [505]	eval-mlogloss:0.00786	train-mlogloss:0.01624
# [506]	eval-mlogloss:0.00786	train-mlogloss:0.01624
# [507]	eval-mlogloss:0.00787	train-mlogloss:0.01624
# [508]	eval-mlogloss:0.00786	train-mlogloss:0.01624
# [509]	eval-mlogloss:0.00786	train-mlogloss:0.01624
# [510]	eval-mlogloss:0.00785	train-mlogloss:0.01624
# [511]	eval-mlogloss:0.00785	train-mlogloss:0.01624
# [512]	eval-mlogloss:0.00784	train-mlogloss:0.01624
# [513]	eval-mlogloss:0.00785	train-mlogloss:0.01624
# [514]	eval-mlogloss:0.00785	train-mlogloss:0.01624
# [515]	eval-mlogloss:0.00784	train-mlogloss:0.01624
# [516]	eval-mlogloss:0.00784	train-mlogloss:0.01623
# [517]	eval-mlogloss:0.00783	train-mlogloss:0.01623
# [518]	eval-mlogloss:0.00784	train-mlogloss:0.01623
# [519]	eval-mlogloss:0.00784	train-mlogloss:0.01623
# [520]	eval-mlogloss:0.00783	train-mlogloss:0.01623
# [521]	eval-mlogloss:0.00783	train-mlogloss:0.01623
# [522]	eval-mlogloss:0.00784	train-mlogloss:0.01623
# [523]	eval-mlogloss:0.00783	train-mlogloss:0.01623
# [524]	eval-mlogloss:0.00783	train-mlogloss:0.01623
# [525]	eval-mlogloss:0.00782	train-mlogloss:0.01623
# [526]	eval-mlogloss:0.00782	train-mlogloss:0.01623
# [527]	eval-mlogloss:0.00781	train-mlogloss:0.01623
# [528]	eval-mlogloss:0.00781	train-mlogloss:0.01623
# [529]	eval-mlogloss:0.00781	train-mlogloss:0.01623
# [530]	eval-mlogloss:0.00780	train-mlogloss:0.01623
# [531]	eval-mlogloss:0.00781	train-mlogloss:0.01623
# [532]	eval-mlogloss:0.00781	train-mlogloss:0.01622
# [533]	eval-mlogloss:0.00780	train-mlogloss:0.01622
# [534]	eval-mlogloss:0.00780	train-mlogloss:0.01622
# [535]	eval-mlogloss:0.00779	train-mlogloss:0.01622
# [536]	eval-mlogloss:0.00780	train-mlogloss:0.01622
# [537]	eval-mlogloss:0.00780	train-mlogloss:0.01622
# [538]	eval-mlogloss:0.00779	train-mlogloss:0.01622
# [539]	eval-mlogloss:0.00779	train-mlogloss:0.01622
# [540]	eval-mlogloss:0.00778	train-mlogloss:0.01622
# [541]	eval-mlogloss:0.00779	train-mlogloss:0.01622
# [542]	eval-mlogloss:0.00779	train-mlogloss:0.01622
# [543]	eval-mlogloss:0.00778	train-mlogloss:0.01622
# [544]	eval-mlogloss:0.00778	train-mlogloss:0.01622
# [545]	eval-mlogloss:0.00779	train-mlogloss:0.01622
# [546]	eval-mlogloss:0.00778	train-mlogloss:0.01622
# [547]	eval-mlogloss:0.00778	train-mlogloss:0.01622
# [548]	eval-mlogloss:0.00777	train-mlogloss:0.01621
# [549]	eval-mlogloss:0.00777	train-mlogloss:0.01621
# [550]	eval-mlogloss:0.00778	train-mlogloss:0.01621
# [551]	eval-mlogloss:0.00777	train-mlogloss:0.01621
# [552]	eval-mlogloss:0.00777	train-mlogloss:0.01621
# [553]	eval-mlogloss:0.00776	train-mlogloss:0.01621
# [554]	eval-mlogloss:0.00776	train-mlogloss:0.01621
# [555]	eval-mlogloss:0.00776	train-mlogloss:0.01621
# [556]	eval-mlogloss:0.00775	train-mlogloss:0.01621
# [557]	eval-mlogloss:0.00775	train-mlogloss:0.01621
# [558]	eval-mlogloss:0.00775	train-mlogloss:0.01621
# [559]	eval-mlogloss:0.00775	train-mlogloss:0.01621
# [560]	eval-mlogloss:0.00775	train-mlogloss:0.01621
# [561]	eval-mlogloss:0.00774	train-mlogloss:0.01621
# [562]	eval-mlogloss:0.00774	train-mlogloss:0.01621
# [563]	eval-mlogloss:0.00774	train-mlogloss:0.01621
# [564]	eval-mlogloss:0.00774	train-mlogloss:0.01621
# [565]	eval-mlogloss:0.00774	train-mlogloss:0.01621
# [566]	eval-mlogloss:0.00773	train-mlogloss:0.01620
# [567]	eval-mlogloss:0.00774	train-mlogloss:0.01620
# [568]	eval-mlogloss:0.00774	train-mlogloss:0.01620
# [569]	eval-mlogloss:0.00773	train-mlogloss:0.01620
# [570]	eval-mlogloss:0.00773	train-mlogloss:0.01620
# [571]	eval-mlogloss:0.00772	train-mlogloss:0.01620
# [572]	eval-mlogloss:0.00772	train-mlogloss:0.01620
# [573]	eval-mlogloss:0.00773	train-mlogloss:0.01620
# [574]	eval-mlogloss:0.00772	train-mlogloss:0.01620
# [575]	eval-mlogloss:0.00772	train-mlogloss:0.01620
# [576]	eval-mlogloss:0.00771	train-mlogloss:0.01620
# [577]	eval-mlogloss:0.00772	train-mlogloss:0.01620
# [578]	eval-mlogloss:0.00772	train-mlogloss:0.01620
# [579]	eval-mlogloss:0.00771	train-mlogloss:0.01620
# [580]	eval-mlogloss:0.00771	train-mlogloss:0.01620
# [581]	eval-mlogloss:0.00772	train-mlogloss:0.01620
# [582]	eval-mlogloss:0.00771	train-mlogloss:0.01620
# [583]	eval-mlogloss:0.00771	train-mlogloss:0.01620
# [584]	eval-mlogloss:0.00770	train-mlogloss:0.01619
# [585]	eval-mlogloss:0.00770	train-mlogloss:0.01619
# [586]	eval-mlogloss:0.00770	train-mlogloss:0.01619
# [587]	eval-mlogloss:0.00769	train-mlogloss:0.01619
# [588]	eval-mlogloss:0.00770	train-mlogloss:0.01619
# [589]	eval-mlogloss:0.00770	train-mlogloss:0.01619
# [590]	eval-mlogloss:0.00769	train-mlogloss:0.01619
# [591]	eval-mlogloss:0.00769	train-mlogloss:0.01619
# [592]	eval-mlogloss:0.00768	train-mlogloss:0.01619
# [593]	eval-mlogloss:0.00769	train-mlogloss:0.01619
# [594]	eval-mlogloss:0.00769	train-mlogloss:0.01619
# [595]	eval-mlogloss:0.00768	train-mlogloss:0.01619
# [596]	eval-mlogloss:0.00768	train-mlogloss:0.01619
# [597]	eval-mlogloss:0.00767	train-mlogloss:0.01619
# [598]	eval-mlogloss:0.00768	train-mlogloss:0.01619
# [599]	eval-mlogloss:0.00768	train-mlogloss:0.01619
# [600]	eval-mlogloss:0.00767	train-mlogloss:0.01619
# [601]	eval-mlogloss:0.00767	train-mlogloss:0.01619
# [602]	eval-mlogloss:0.00768	train-mlogloss:0.01619
# [603]	eval-mlogloss:0.00767	train-mlogloss:0.01618
# [604]	eval-mlogloss:0.00767	train-mlogloss:0.01618
# [605]	eval-mlogloss:0.00766	train-mlogloss:0.01618
# [606]	eval-mlogloss:0.00766	train-mlogloss:0.01618
# [607]	eval-mlogloss:0.00765	train-mlogloss:0.01618
# [608]	eval-mlogloss:0.00766	train-mlogloss:0.01618
# [609]	eval-mlogloss:0.00766	train-mlogloss:0.01618
# [610]	eval-mlogloss:0.00765	train-mlogloss:0.01618
# [611]	eval-mlogloss:0.00765	train-mlogloss:0.01618
# [612]	eval-mlogloss:0.00766	train-mlogloss:0.01618
# [613]	eval-mlogloss:0.00765	train-mlogloss:0.01618
# [614]	eval-mlogloss:0.00765	train-mlogloss:0.01618
# [615]	eval-mlogloss:0.00764	train-mlogloss:0.01618
# [616]	eval-mlogloss:0.00765	train-mlogloss:0.01618
# [617]	eval-mlogloss:0.00765	train-mlogloss:0.01618
# [618]	eval-mlogloss:0.00764	train-mlogloss:0.01618
# [619]	eval-mlogloss:0.00764	train-mlogloss:0.01618
# [620]	eval-mlogloss:0.00764	train-mlogloss:0.01618
# [621]	eval-mlogloss:0.00763	train-mlogloss:0.01618
# [622]	eval-mlogloss:0.00763	train-mlogloss:0.01618
# [623]	eval-mlogloss:0.00763	train-mlogloss:0.01617
# [624]	eval-mlogloss:0.00763	train-mlogloss:0.01617
# [625]	eval-mlogloss:0.00763	train-mlogloss:0.01617
# [626]	eval-mlogloss:0.00763	train-mlogloss:0.01617
# [627]	eval-mlogloss:0.00763	train-mlogloss:0.01617
# [628]	eval-mlogloss:0.00763	train-mlogloss:0.01617
# [629]	eval-mlogloss:0.00762	train-mlogloss:0.01617
# [630]	eval-mlogloss:0.00762	train-mlogloss:0.01617
# [631]	eval-mlogloss:0.00761	train-mlogloss:0.01617
# [632]	eval-mlogloss:0.00762	train-mlogloss:0.01617
# [633]	eval-mlogloss:0.00762	train-mlogloss:0.01617
# [634]	eval-mlogloss:0.00761	train-mlogloss:0.01617
# [635]	eval-mlogloss:0.00761	train-mlogloss:0.01617
# [636]	eval-mlogloss:0.00760	train-mlogloss:0.01617
# [637]	eval-mlogloss:0.00761	train-mlogloss:0.01617
# [638]	eval-mlogloss:0.00761	train-mlogloss:0.01617
# [639]	eval-mlogloss:0.00760	train-mlogloss:0.01617
# [640]	eval-mlogloss:0.00760	train-mlogloss:0.01617
# [641]	eval-mlogloss:0.00761	train-mlogloss:0.01617
# [642]	eval-mlogloss:0.00760	train-mlogloss:0.01617
# [643]	eval-mlogloss:0.00760	train-mlogloss:0.01617
# [644]	eval-mlogloss:0.00759	train-mlogloss:0.01616
# [645]	eval-mlogloss:0.00759	train-mlogloss:0.01616
# [646]	eval-mlogloss:0.00760	train-mlogloss:0.01616
# [647]	eval-mlogloss:0.00759	train-mlogloss:0.01616
# [648]	eval-mlogloss:0.00759	train-mlogloss:0.01616
# [649]	eval-mlogloss:0.00759	train-mlogloss:0.01616
# [650]	eval-mlogloss:0.00759	train-mlogloss:0.01616
# [651]	eval-mlogloss:0.00759	train-mlogloss:0.01616
# [652]	eval-mlogloss:0.00758	train-mlogloss:0.01616
# [653]	eval-mlogloss:0.00759	train-mlogloss:0.01616
# [654]	eval-mlogloss:0.00759	train-mlogloss:0.01616
# [655]	eval-mlogloss:0.00758	train-mlogloss:0.01616
# [656]	eval-mlogloss:0.00758	train-mlogloss:0.01616
# [657]	eval-mlogloss:0.00759	train-mlogloss:0.01616
# [658]	eval-mlogloss:0.00758	train-mlogloss:0.01616
# [659]	eval-mlogloss:0.00758	train-mlogloss:0.01616
# [660]	eval-mlogloss:0.00757	train-mlogloss:0.01616
# [661]	eval-mlogloss:0.00757	train-mlogloss:0.01616
# [662]	eval-mlogloss:0.00756	train-mlogloss:0.01616
# [663]	eval-mlogloss:0.00757	train-mlogloss:0.01616
# [664]	eval-mlogloss:0.00757	train-mlogloss:0.01616
# [665]	eval-mlogloss:0.00756	train-mlogloss:0.01616
# [666]	eval-mlogloss:0.00757	train-mlogloss:0.01615
# [667]	eval-mlogloss:0.00757	train-mlogloss:0.01615
# [668]	eval-mlogloss:0.00756	train-mlogloss:0.01615
# [669]	eval-mlogloss:0.00756	train-mlogloss:0.01615
# [670]	eval-mlogloss:0.00756	train-mlogloss:0.01615
# [671]	eval-mlogloss:0.00756	train-mlogloss:0.01615
# [672]	eval-mlogloss:0.00756	train-mlogloss:0.01615
# [673]	eval-mlogloss:0.00755	train-mlogloss:0.01615
# [674]	eval-mlogloss:0.00755	train-mlogloss:0.01615
# [675]	eval-mlogloss:0.00755	train-mlogloss:0.01615
# [676]	eval-mlogloss:0.00755	train-mlogloss:0.01615
# [677]	eval-mlogloss:0.00755	train-mlogloss:0.01615
# [678]	eval-mlogloss:0.00755	train-mlogloss:0.01615
# [679]	eval-mlogloss:0.00754	train-mlogloss:0.01615
# [680]	eval-mlogloss:0.00754	train-mlogloss:0.01615
# [681]	eval-mlogloss:0.00754	train-mlogloss:0.01615
# [682]	eval-mlogloss:0.00754	train-mlogloss:0.01615
# [683]	eval-mlogloss:0.00754	train-mlogloss:0.01615
# [684]	eval-mlogloss:0.00754	train-mlogloss:0.01615
# [685]	eval-mlogloss:0.00754	train-mlogloss:0.01615
# [686]	eval-mlogloss:0.00754	train-mlogloss:0.01615
# [687]	eval-mlogloss:0.00753	train-mlogloss:0.01615
# [688]	eval-mlogloss:0.00754	train-mlogloss:0.01615
# [689]	eval-mlogloss:0.00754	train-mlogloss:0.01614
# [690]	eval-mlogloss:0.00753	train-mlogloss:0.01614
# [691]	eval-mlogloss:0.00753	train-mlogloss:0.01614
# [692]	eval-mlogloss:0.00752	train-mlogloss:0.01614
# [693]	eval-mlogloss:0.00752	train-mlogloss:0.01614
# [694]	eval-mlogloss:0.00753	train-mlogloss:0.01614
# [695]	eval-mlogloss:0.00752	train-mlogloss:0.01614
# [696]	eval-mlogloss:0.00752	train-mlogloss:0.01614
# [697]	eval-mlogloss:0.00752	train-mlogloss:0.01614
# [698]	eval-mlogloss:0.00752	train-mlogloss:0.01614
# [699]	eval-mlogloss:0.00752	train-mlogloss:0.01614
# [700]	eval-mlogloss:0.00751	train-mlogloss:0.01614
# [701]	eval-mlogloss:0.00751	train-mlogloss:0.01614
# [702]	eval-mlogloss:0.00751	train-mlogloss:0.01614
# [703]	eval-mlogloss:0.00751	train-mlogloss:0.01614
# [704]	eval-mlogloss:0.00751	train-mlogloss:0.01614
# [705]	eval-mlogloss:0.00750	train-mlogloss:0.01614
# [706]	eval-mlogloss:0.00751	train-mlogloss:0.01614
# [707]	eval-mlogloss:0.00751	train-mlogloss:0.01614
# [708]	eval-mlogloss:0.00750	train-mlogloss:0.01614
# [709]	eval-mlogloss:0.00750	train-mlogloss:0.01614
# [710]	eval-mlogloss:0.00751	train-mlogloss:0.01614
# [711]	eval-mlogloss:0.00750	train-mlogloss:0.01614
# [712]	eval-mlogloss:0.00750	train-mlogloss:0.01614
# [713]	eval-mlogloss:0.00749	train-mlogloss:0.01613
# [714]	eval-mlogloss:0.00750	train-mlogloss:0.01613
# [715]	eval-mlogloss:0.00750	train-mlogloss:0.01613
# [716]	eval-mlogloss:0.00749	train-mlogloss:0.01613
# [717]	eval-mlogloss:0.00749	train-mlogloss:0.01613
# [718]	eval-mlogloss:0.00750	train-mlogloss:0.01613
# [719]	eval-mlogloss:0.00749	train-mlogloss:0.01613
# [720]	eval-mlogloss:0.00749	train-mlogloss:0.01613
# [721]	eval-mlogloss:0.00748	train-mlogloss:0.01613
# [722]	eval-mlogloss:0.00749	train-mlogloss:0.01613
# [723]	eval-mlogloss:0.00749	train-mlogloss:0.01613
# [724]	eval-mlogloss:0.00748	train-mlogloss:0.01613
# [725]	eval-mlogloss:0.00748	train-mlogloss:0.01613
# [726]	eval-mlogloss:0.00749	train-mlogloss:0.01613
# [727]	eval-mlogloss:0.00748	train-mlogloss:0.01613
# [728]	eval-mlogloss:0.00748	train-mlogloss:0.01613
# [729]	eval-mlogloss:0.00747	train-mlogloss:0.01613
# [730]	eval-mlogloss:0.00748	train-mlogloss:0.01613
# [731]	eval-mlogloss:0.00748	train-mlogloss:0.01613
# [732]	eval-mlogloss:0.00747	train-mlogloss:0.01613
# [733]	eval-mlogloss:0.00747	train-mlogloss:0.01613
# [734]	eval-mlogloss:0.00746	train-mlogloss:0.01613
# [735]	eval-mlogloss:0.00747	train-mlogloss:0.01613
# [736]	eval-mlogloss:0.00747	train-mlogloss:0.01613
# [737]	eval-mlogloss:0.00746	train-mlogloss:0.01613
# [738]	eval-mlogloss:0.00746	train-mlogloss:0.01613
# [739]	eval-mlogloss:0.00746	train-mlogloss:0.01612
# [740]	eval-mlogloss:0.00746	train-mlogloss:0.01612
# [741]	eval-mlogloss:0.00746	train-mlogloss:0.01612
# [742]	eval-mlogloss:0.00746	train-mlogloss:0.01612
# [743]	eval-mlogloss:0.00746	train-mlogloss:0.01612
# [744]	eval-mlogloss:0.00746	train-mlogloss:0.01612
# [745]	eval-mlogloss:0.00745	train-mlogloss:0.01612
# [746]	eval-mlogloss:0.00745	train-mlogloss:0.01612
# [747]	eval-mlogloss:0.00745	train-mlogloss:0.01612
# [748]	eval-mlogloss:0.00745	train-mlogloss:0.01612
# [749]	eval-mlogloss:0.00745	train-mlogloss:0.01612
# [750]	eval-mlogloss:0.00745	train-mlogloss:0.01612
# [751]	eval-mlogloss:0.00745	train-mlogloss:0.01612
# [752]	eval-mlogloss:0.00745	train-mlogloss:0.01612
# [753]	eval-mlogloss:0.00744	train-mlogloss:0.01612
# [754]	eval-mlogloss:0.00744	train-mlogloss:0.01612
# [755]	eval-mlogloss:0.00745	train-mlogloss:0.01612
# [756]	eval-mlogloss:0.00744	train-mlogloss:0.01612
# [757]	eval-mlogloss:0.00744	train-mlogloss:0.01612
# [758]	eval-mlogloss:0.00745	train-mlogloss:0.01612
# [759]	eval-mlogloss:0.00744	train-mlogloss:0.01612
# [760]	eval-mlogloss:0.00744	train-mlogloss:0.01612
# [761]	eval-mlogloss:0.00743	train-mlogloss:0.01612
# [762]	eval-mlogloss:0.00743	train-mlogloss:0.01612
# [763]	eval-mlogloss:0.00743	train-mlogloss:0.01612
# [764]	eval-mlogloss:0.00743	train-mlogloss:0.01612
# [765]	eval-mlogloss:0.00743	train-mlogloss:0.01612
# [766]	eval-mlogloss:0.00743	train-mlogloss:0.01611
# [767]	eval-mlogloss:0.00742	train-mlogloss:0.01611
# [768]	eval-mlogloss:0.00743	train-mlogloss:0.01611
# [769]	eval-mlogloss:0.00742	train-mlogloss:0.01611
# [770]	eval-mlogloss:0.00742	train-mlogloss:0.01611
# [771]	eval-mlogloss:0.00742	train-mlogloss:0.01611
# [772]	eval-mlogloss:0.00742	train-mlogloss:0.01611
# [773]	eval-mlogloss:0.00742	train-mlogloss:0.01611
# [774]	eval-mlogloss:0.00743	train-mlogloss:0.01611
# [775]	eval-mlogloss:0.00742	train-mlogloss:0.01611
# [776]	eval-mlogloss:0.00742	train-mlogloss:0.01611
# [777]	eval-mlogloss:0.00741	train-mlogloss:0.01611
# [778]	eval-mlogloss:0.00741	train-mlogloss:0.01611
# [779]	eval-mlogloss:0.00741	train-mlogloss:0.01611
# [780]	eval-mlogloss:0.00741	train-mlogloss:0.01611
# [781]	eval-mlogloss:0.00741	train-mlogloss:0.01611
# [782]	eval-mlogloss:0.00741	train-mlogloss:0.01611
# [783]	eval-mlogloss:0.00741	train-mlogloss:0.01611
# [784]	eval-mlogloss:0.00741	train-mlogloss:0.01611
# [785]	eval-mlogloss:0.00740	train-mlogloss:0.01611
# [786]	eval-mlogloss:0.00741	train-mlogloss:0.01611
# [787]	eval-mlogloss:0.00741	train-mlogloss:0.01611
# [788]	eval-mlogloss:0.00740	train-mlogloss:0.01611
# [789]	eval-mlogloss:0.00740	train-mlogloss:0.01611
# [790]	eval-mlogloss:0.00741	train-mlogloss:0.01611
# [791]	eval-mlogloss:0.00740	train-mlogloss:0.01611
# [792]	eval-mlogloss:0.00740	train-mlogloss:0.01611
# [793]	eval-mlogloss:0.00739	train-mlogloss:0.01611
# [794]	eval-mlogloss:0.00740	train-mlogloss:0.01611
# [795]	eval-mlogloss:0.00740	train-mlogloss:0.01610
# [796]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [797]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [798]	eval-mlogloss:0.00740	train-mlogloss:0.01610
# [799]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [800]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [801]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [802]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [803]	eval-mlogloss:0.00740	train-mlogloss:0.01610
# [804]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [805]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [806]	eval-mlogloss:0.00740	train-mlogloss:0.01610
# [807]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [808]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [809]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [810]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [811]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [812]	eval-mlogloss:0.00738	train-mlogloss:0.01610
# [813]	eval-mlogloss:0.00738	train-mlogloss:0.01610
# [814]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [815]	eval-mlogloss:0.00738	train-mlogloss:0.01610
# [816]	eval-mlogloss:0.00738	train-mlogloss:0.01610
# [817]	eval-mlogloss:0.00739	train-mlogloss:0.01610
# [818]	eval-mlogloss:0.00738	train-mlogloss:0.01610
# [819]	eval-mlogloss:0.00738	train-mlogloss:0.01610
# [820]	eval-mlogloss:0.00737	train-mlogloss:0.01610
# [821]	eval-mlogloss:0.00737	train-mlogloss:0.01610
# [822]	eval-mlogloss:0.00737	train-mlogloss:0.01610
# [823]	eval-mlogloss:0.00737	train-mlogloss:0.01610
# [824]	eval-mlogloss:0.00737	train-mlogloss:0.01610
# [825]	eval-mlogloss:0.00737	train-mlogloss:0.01610
# [826]	eval-mlogloss:0.00737	train-mlogloss:0.01609
# [827]	eval-mlogloss:0.00737	train-mlogloss:0.01609
# [828]	eval-mlogloss:0.00737	train-mlogloss:0.01609
# [829]	eval-mlogloss:0.00737	train-mlogloss:0.01609
# [830]	eval-mlogloss:0.00737	train-mlogloss:0.01609
# [831]	eval-mlogloss:0.00736	train-mlogloss:0.01609
# [832]	eval-mlogloss:0.00736	train-mlogloss:0.01609
# [833]	eval-mlogloss:0.00736	train-mlogloss:0.01609
# [834]	eval-mlogloss:0.00736	train-mlogloss:0.01609
# [835]	eval-mlogloss:0.00736	train-mlogloss:0.01609
# [836]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [837]	eval-mlogloss:0.00736	train-mlogloss:0.01609
# [838]	eval-mlogloss:0.00736	train-mlogloss:0.01609
# [839]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [840]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [841]	eval-mlogloss:0.00736	train-mlogloss:0.01609
# [842]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [843]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [844]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [845]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [846]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [847]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [848]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [849]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [850]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [851]	eval-mlogloss:0.00736	train-mlogloss:0.01609
# [852]	eval-mlogloss:0.00736	train-mlogloss:0.01609
# [853]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [854]	eval-mlogloss:0.00735	train-mlogloss:0.01609
# [855]	eval-mlogloss:0.00734	train-mlogloss:0.01609
# [856]	eval-mlogloss:0.00734	train-mlogloss:0.01609
# [857]	eval-mlogloss:0.00734	train-mlogloss:0.01609
# [858]	eval-mlogloss:0.00734	train-mlogloss:0.01608
# [859]	eval-mlogloss:0.00734	train-mlogloss:0.01608
# [860]	eval-mlogloss:0.00734	train-mlogloss:0.01608
# [861]	eval-mlogloss:0.00734	train-mlogloss:0.01608
# [862]	eval-mlogloss:0.00734	train-mlogloss:0.01608
# [863]	eval-mlogloss:0.00734	train-mlogloss:0.01608
# [864]	eval-mlogloss:0.00734	train-mlogloss:0.01608
# [865]	eval-mlogloss:0.00734	train-mlogloss:0.01608
# [866]	eval-mlogloss:0.00734	train-mlogloss:0.01608
# [867]	eval-mlogloss:0.00734	train-mlogloss:0.01608
# [868]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [869]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [870]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [871]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [872]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [873]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [874]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [875]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [876]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [877]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [878]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [879]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [880]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [881]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [882]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [883]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [884]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [885]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [886]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [887]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [888]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [889]	eval-mlogloss:0.00733	train-mlogloss:0.01608
# [890]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [891]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [892]	eval-mlogloss:0.00732	train-mlogloss:0.01608
# [893]	eval-mlogloss:0.00732	train-mlogloss:0.01607
# [894]	eval-mlogloss:0.00732	train-mlogloss:0.01607
# [895]	eval-mlogloss:0.00732	train-mlogloss:0.01607
# [896]	eval-mlogloss:0.00732	train-mlogloss:0.01607
# [897]	eval-mlogloss:0.00732	train-mlogloss:0.01607
# [898]	eval-mlogloss:0.00731	train-mlogloss:0.01607
# [899]	eval-mlogloss:0.00731	train-mlogloss:0.01607
# [900]	eval-mlogloss:0.00731	train-mlogloss:0.01607
# [901]	eval-mlogloss:0.00731	train-mlogloss:0.01607
# [902]	eval-mlogloss:0.00731	train-mlogloss:0.01607
# [903]	eval-mlogloss:0.00730	train-mlogloss:0.01607
# [904]	eval-mlogloss:0.00731	train-mlogloss:0.01607
# [905]	eval-mlogloss:0.00731	train-mlogloss:0.01607
# [906]	eval-mlogloss:0.00730	train-mlogloss:0.01607
# [907]	eval-mlogloss:0.00731	train-mlogloss:0.01607
# [908]	eval-mlogloss:0.00731	train-mlogloss:0.01607
# [909]	eval-mlogloss:0.00730	train-mlogloss:0.01607
# [910]	eval-mlogloss:0.00730	train-mlogloss:0.01607
# [911]	eval-mlogloss:0.00731	train-mlogloss:0.01607
# [912]	eval-mlogloss:0.00730	train-mlogloss:0.01607
# [913]	eval-mlogloss:0.00730	train-mlogloss:0.01607
# [914]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [915]	eval-mlogloss:0.00730	train-mlogloss:0.01607
# [916]	eval-mlogloss:0.00730	train-mlogloss:0.01607
# [917]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [918]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [919]	eval-mlogloss:0.00730	train-mlogloss:0.01607
# [920]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [921]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [922]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [923]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [924]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [925]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [926]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [927]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [928]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [929]	eval-mlogloss:0.00729	train-mlogloss:0.01607
# [930]	eval-mlogloss:0.00728	train-mlogloss:0.01606
# [931]	eval-mlogloss:0.00728	train-mlogloss:0.01606
# [932]	eval-mlogloss:0.00728	train-mlogloss:0.01606
# [933]	eval-mlogloss:0.00729	train-mlogloss:0.01606
# [934]	eval-mlogloss:0.00729	train-mlogloss:0.01606
# [935]	eval-mlogloss:0.00728	train-mlogloss:0.01606
# [936]	eval-mlogloss:0.00728	train-mlogloss:0.01606
# [937]	eval-mlogloss:0.00728	train-mlogloss:0.01606
# [938]	eval-mlogloss:0.00728	train-mlogloss:0.01606
# [939]	eval-mlogloss:0.00728	train-mlogloss:0.01606
# [940]	eval-mlogloss:0.00728	train-mlogloss:0.01606
# [941]	eval-mlogloss:0.00728	train-mlogloss:0.01606
# [942]	eval-mlogloss:0.00728	train-mlogloss:0.01606
# ...
# [4043]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4044]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4045]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4046]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4047]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4048]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4049]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4050]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4051]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4052]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4053]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4054]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4055]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4056]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4057]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4058]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4059]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4060]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4061]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4062]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4063]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4064]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4065]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4066]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4067]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4068]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4069]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4070]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4071]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4072]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4073]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4074]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4075]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4076]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4077]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4078]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4079]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4080]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4081]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4082]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4083]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4084]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4085]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4086]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4087]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4088]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4089]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4090]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4091]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4092]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4093]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4094]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4095]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4096]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4097]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4098]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4099]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4100]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4101]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4102]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4103]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4104]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4105]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4106]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4107]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4108]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4109]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4110]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4111]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4112]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4113]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4114]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4115]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4116]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4117]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4118]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4119]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4120]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4121]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4122]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4123]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4124]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4125]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4126]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4127]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4128]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4129]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4130]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4131]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4132]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4133]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4134]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4135]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4136]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4137]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4138]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4139]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4140]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4141]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4142]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4143]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4144]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4145]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4146]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4147]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4148]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4149]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4150]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4151]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4152]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4153]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4154]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4155]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4156]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4157]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4158]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4159]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4160]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4161]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4162]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4163]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4164]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4165]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4166]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4167]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4168]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4169]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4170]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4171]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4172]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4173]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4174]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4175]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4176]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4177]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4178]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4179]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4180]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4181]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4182]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4183]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4184]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4185]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4186]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4187]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4188]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4189]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4190]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4191]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4192]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4193]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4194]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4195]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4196]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4197]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4198]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4199]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4200]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4201]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4202]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4203]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4204]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4205]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4206]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4207]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4208]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4209]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4210]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4211]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4212]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4213]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4214]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4215]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4216]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4217]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4218]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4219]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4220]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4221]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4222]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4223]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4224]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4225]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4226]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4227]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4228]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4229]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4230]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4231]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4232]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4233]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4234]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4235]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4236]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4237]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4238]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4239]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4240]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4241]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4242]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4243]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4244]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4245]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4246]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4247]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4248]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4249]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4250]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4251]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4252]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4253]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4254]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4255]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4256]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4257]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4258]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4259]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4260]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4261]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4262]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4263]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4264]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4265]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4266]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4267]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4268]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4269]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4270]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4271]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4272]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4273]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4274]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4275]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4276]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4277]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4278]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4279]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4280]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4281]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4282]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4283]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4284]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4285]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4286]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4287]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4288]	eval-mlogloss:0.00681	train-mlogloss:0.01589
# [4289]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4290]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4291]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4292]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4293]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4294]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4295]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4296]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4297]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4298]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4299]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4300]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4301]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4302]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4303]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4304]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4305]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4306]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4307]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4308]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4309]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4310]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4311]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4312]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4313]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4314]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4315]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4316]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4317]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4318]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4319]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4320]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4321]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4322]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4323]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4324]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4325]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4326]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4327]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4328]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4329]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4330]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4331]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4332]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4333]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4334]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4335]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4336]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4337]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4338]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4339]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4340]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4341]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4342]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4343]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4344]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4345]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4346]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4347]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4348]	eval-mlogloss:0.00680	train-mlogloss:0.01589
# [4349]	eval-mlogloss:0.00680	train-mlogloss:0.01589

# %% [markdown]
# ## [2-5] Confirming the result of the validation

# %%
#print('Best Score:{0:.4f}, Iteration:{1:d}, Ntree_limit:{2:d}'.format(bst.best_score,bst.best_iteration,bst.best_ntree_limit))
#print('Best Score:{0:.4f}, Iteratin:{1:d}, Ntree_Limit:{2:d}'.format(
#     bst.best_score, bst.best_iteration, bst.best_ntree_limit))
# Best Score:0.0186, Iteratin:1153, Ntree_Limit:1154
bst.attributes()
# Out:
# {'best_iteration': '4344', 'best_score': '0.01588832423423507'}

# %% [markdown]
# ## [2-6] Prediction
#
# Performing predictions with the model that had the best results out of the validation results.

# %%
dtest = xgb.DMatrix(test_x)
pred = ypred = bst.predict(dtest)
#ntree_limit = bst.best_ntree_limit

# %%
print(ypred)
# Out:
# [2. 1. 2. 2. 0. 2. 2. 2. 0. 0. 0. 0. 2. 0. 1. 1. 2. 1. 2. 2. 2. 1. 2. 1.
#  2. 1. 0. 0. 1. 2.]

# %% [markdown]
# ## Finally
#
# For people with experience in machine learning, using the pandas DataFrame and Series might have seemed easy.
#
# This example was about multiple class classification, but can just as well be used for binary classification and regression. This approach can be helpful in many different situations.

# %%
### End of J->E, switch E->J

# %% [markdown]
# ## Shap
#
# Shap is a python package that allows you to analyze and debug you models.
# Shap values are used to explain individual model predictions, informing about how much a feature has influenced the prediciton.
#
# while feature importance informs about how a feature affects the predictions in general, shap values give insight into how features influences **individual predicitons**.
#
# Esentially gives you an understanding of how machine learning models work.

# %% [markdown]
# ## SHAP
#
# SHAPは機械学習モデルの解析とデバッグを可能にするpythonパッケージです。
# そのパッケージはモデルの予測のシャープレイ値を算出し、特徴量ごとが予測の影響が分かるようになります。
#
#
# while feature importance informs about how a feature affects the predictions in general, shap values give insight into how features influences **individual predicitons**.
#
# Esentially gives you an understanding of how machine learning models work.

# %% [markdown]
# ## Shapley Values
#
# Shapely values are a concept from cooperative game theroy to provide a way to fairly distribute the payoff of a cooperative game among players based on their contributions.
# They are a method for assigning a fair share of the total payoff to each player in as cooperative game. They are based on the idea of marginal contributions: the additional value each player brings when joining a coalition.
#
# The calculation of Shapley values involve considering all possible permutations of players joining the coalition and computing the marginal contribution of each player to each possible permutation. The Shapley value of a player is then the average of their marginal controbition over all possible permutations.
#
# In the context of machine learning,
#
# [source](https://www.youtube.com/watch?v=UJeu29wq7d0&list=PLqDyyww9y-1SJgMw92x90qPYpHgahDLIK&index=3)

# %%
## Shap

# %% [markdown]
# ## Using Shap
#
# Since shap is a package it needs to be imported alongside a few other packages that make working with it a bit more easier.
# This includes the matplotlib, pandas, numpy and seaborn package.
# Since pandas is already in this scrip, it will not be imported.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import shap

# %% [markdown]
# Shap also needs to be initilaized  in order to be able to be used.

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...

# %% [markdown]
# The shap.TreeExplainer function desinged to explain prediction made by tree based models, such as the gradient tree bosting algorythm in this case.
# It takes in a model a model as an argument and then provides the shapley values for each feature in each prediction made in the provided data set.

# %%
explainer = shap.TreeExplainer(bst)
shap_values = explainer(test_x)

# %% [markdown]
# For continuous or binary predictions, the explainer returns a list of arrays that contain a shapley value for each feature in each input data, in other words, a shapley value for each feature value.
# However in this case, since we have a multi class classification, the shapley values for each input are calculated for each class.
# The sum of the values show the probaility of the input being of that specific class and the model selects the one with the hightest probabiliy as the output of the model.

# %%
print(np.shape(shap_values))
# Out:
# (30, 4, 3)

# %% [markdown]
# Here we show the waterfalldiagramms for all three classes of for the second row of the data.

# %%
shap.plots.waterfall(shap_values[1,:,0])
shap.plots.waterfall(shap_values[1,:,1])
shap.plots.waterfall(shap_values[1,:,2])

# %% [markdown]
# In this case, this data was predicted to be of the 2nd type of class. From the charts below we can see that this matches both the predicted, and the manual classifications match.

# %%
print(test_x)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 70                 5.9               3.2                4.8               1.8
# 81                 5.5               2.4                3.7               1.0
# 142                5.8               2.7                5.1               1.9
# 144                6.7               3.3                5.7               2.5
# 45                 4.8               3.0                1.4               0.3
# 136                6.3               3.4                5.6               2.4
# 111                6.4               2.7                5.3               1.9
# 124                6.7               3.3                5.7               2.1
# 10                 5.4               3.7                1.5               0.2
# 5                  5.4               3.9                1.7               0.4
# 21                 5.1               3.7                1.5               0.4
# 29                 4.7               3.2                1.6               0.2
# 118                7.7               2.6                6.9               2.3
# 2                  4.7               3.2                1.3               0.2
# 95                 5.7               3.0                4.2               1.2
# 93                 5.0               2.3                3.3               1.0
# 117                7.7               3.8                6.7               2.2
# 60                 5.0               2.0                3.5               1.0
# 130                7.4               2.8                6.1               1.9
# 147                6.5               3.0                5.2               2.0
# 120                6.9               3.2                5.7               2.3
# 91                 6.1               3.0                4.6               1.4
# 112                6.8               3.0                5.5               2.1
# 89                 5.5               2.5                4.0               1.3
# 114                5.8               2.8                5.1               2.4
# 94                 5.6               2.7                4.2               1.3
# 28                 5.2               3.4                1.4               0.2
# 8                  4.4               2.9                1.4               0.2
# 56                 6.3               3.3                4.7               1.6
# 102                7.1               3.0                5.9               2.1

# %%
print(test_y)
# Out:
# 70     1
# 81     1
# 142    2
# 144    2
# 45     0
# 136    2
# 111    2
# 124    2
# 10     0
# 5      0
# 21     0
# 29     0
# 118    2
# 2      0
# 95     1
# 93     1
# 117    2
# 60     1
# 130    2
# 147    2
# 120    2
# 91     1
# 112    2
# 89     1
# 114    2
# 94     1
# 28     0
# 8      0
# 56     1
# 102    2
# dtype: int32

# %%
print(shap_values[1])
# Out:
# .values =
# array([[ 0.        , -3.2881975 , -0.36858726],
#        [ 0.        ,  0.5025524 ,  1.0725242 ],
#        [-2.3609805 ,  4.136837  , -2.3654892 ],
#        [ 0.        , -0.67195255, -2.6597502 ]], dtype=float32)
#
# .base_values =
# array([-0.04305708,  1.7767287 ,  2.371655  ], dtype=float32)
#
# .data =
# array([5.5, 2.4, 3.7, 1. ])

# %% [markdown]
# Calculating the absolute mean of the shap values.

# %%
mean_0 = np.mean(np.abs(shap_values.values[:,:,0]),axis =0)
mean_1 = np.mean(np.abs(shap_values.values[:,:,1]),axis =0)
mean_2 = np.mean(np.abs(shap_values.values[:,:,2]),axis =0)

df= pd.DataFrame({"Class0": mean_0,"Class1": mean_1,"Class2": mean_2})

fig, ax  = plt.subplots(1,1, figsize =(20,10))
df.plot.bar(ax= ax)

ax.set_ylabel("Mean SHAP", size = 30)
ax.set_xticklabels(iris.feature_names, rotation = 45, size = 20)
ax.legend(fontsize = 30)

# %% [markdown]
# shap values for only the predicted class

# %%
new_shap_values =[]
for i, pre in enumerate(pred) :
    #print(pre)
    #print(i)
    new_shap_values.append(shap_values.values[i][:,int(pre)])

shap_values.values = np.array(new_shap_values)
print(shap_values.shape)
# Out:
# (30, 4)

# %%
shap.plots.bar(shap_values)

# %%
shap.plots.beeswarm(shap_values)
